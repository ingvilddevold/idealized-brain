# %% [markdown]
# ### Multidomain Mesh Generation with fTetWild
#
# In this notebook, we demonstrate how to generate a multidomain idealized brain mesh using boolean operations on surface meshes (STLs) with [fTetWild](https://wildmeshing.github.io/ftetwild/).
#
# First, we import the relevant packages and set the ids of the subdomains and boundaries we want to mark:

# %%
import wildmeshing as wm
import pyvista as pv
import numpy as np
import meshio
import json
from pathlib import Path

# domain ids
porous_id = 1
fluid_id = 2

# facet ids
#skull_id = 1
#spinal_canal_id = 2
#interface_id = 3
#spinal_cord_id = 4
#aqueduct_V4_id = 5

interface_id = 1
skull_id = 2
spinal_canal_id = 3
spinal_cord_id = 4
aqueduct_V4_id = 5

# %% [markdown]
# As our geometry consists of multiple spheres and cylinders, we create surface meshes for each of the components with PyVista and plot them to check the setup:

# %%
skull = pv.Sphere(radius = 0.08)
parenchyma = pv.Sphere(radius = 0.07)
ventricle = pv.Sphere(radius = 0.02)
canal = pv.Cylinder(center=(0, 0, -0.105), direction=(0,0,-1),
                        radius=0.025, height=0.08).triangulate()
cord = pv.Cylinder(center=(0, 0, -0.105), direction=(0,0,-1),
                        radius=0.017, height=0.08).triangulate()
aqueduct = pv.Cylinder(center=(0, 0.03, -0.03), direction=(0,1,-1),
                       radius=0.004, height=0.06).triangulate()

# display the geometry using PyVista
pl = pv.Plotter()
pl.add_mesh(parenchyma, opacity=.6, color="blue")
pl.add_mesh(ventricle,  color="red")
pl.add_mesh(aqueduct, opacity=0.7, color="red")
pl.add_mesh(skull, opacity=0.2)
pl.add_mesh(canal, opacity=0.2)
pl.add_mesh(cord, opacity=0.7, color="blue")
pl.background_color = "white"
pl.show()
# Out:
# /Users/ingvildsd/miniforge3/envs/brainpulse_new/lib/python3.13/site-packages/pyvista/jupyter/notebook.py:56: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
# save the surface meshes for later use by fTetWild
stl_directory = Path("stls/")
stl_directory.mkdir(exist_ok=True, parents=True)
parenchyma.save(stl_directory / "parenchyma.stl")
skull.save(stl_directory / "skull.stl")
cord.save(stl_directory / "cord.stl")
canal.save(stl_directory / "canal.stl")
ventricle.save(stl_directory / "ventricle.stl")
aqueduct.save(stl_directory / "aqueduct.stl")

# %% [markdown]
# Now, we have everything in place to define a constructive solid geometry(CSG)-tree, describing the order and type of boolean operations carried out on the surface meshes:
#
# * first, we take the union of brain tissue components: parenchyma and spinal cord
# * then, we subtract the ventricle and aqueduct parts from the tissue
# * finally, we take the union of the outermost sphere and cylinder with the result of the previous steps
#
# Further, we specify maximum distance between the input surfaces and the surface of the generated volumetric mesh with the *epsilon* parameter (specifying the relative envelop size) and relative edge length with *edge_length_r*.
#
# Note that while we use a simple geometry here, we can easily replace the STL files with complex shapes and apply the same procedure to generate image-derived realistic models.

# %%
tetra = wm.Tetrahedralizer(epsilon=0.002, edge_length_r=0.05,
                           coarsen=False)
tetra.load_csg_tree(json.dumps(
    {"operation":"union",
     "right":
          {
          "operation":"difference",
          "left":{"operation":"union", "left": str(stl_directory / "parenchyma.stl"),
                              "right": str(stl_directory / "cord.stl")},
          "right":{"operation":"union", "left": str(stl_directory / "aqueduct.stl"),
                          "right":str(stl_directory / "ventricle.stl")},
          },
     "left":
        {"operation":"union", "left": str(stl_directory / "skull.stl"),
                          "right":str(stl_directory / "canal.stl")},                
    }
))
tetra.tetrahedralize()
point_array, cell_array, marker = tetra.get_tet_mesh()
# Out:
# TBB threads 12
# o-[I/O         ] Loading file stls/skull.stl...
#                  (FP64) nb_v:5040 nb_e:0 nb_f:1680 nb_b:5040 tri:1 dim:3
#                  Attributes on vertices: point[3]
#                  Loading file stls/canal.stl...
#                  (FP64) nb_v:1188 nb_e:0 nb_f:396 nb_b:1188 tri:1 dim:3
#                  Attributes on vertices: point[3]
#                  Loading file stls/parenchyma.stl...
#                  (FP64) nb_v:5040 nb_e:0 nb_f:1680 nb_b:5040 tri:1 dim:3
#                  Attributes on vertices: point[3]
#                  Loading file stls/cord.stl...
#                  (FP64) nb_v:1188 nb_e:0 nb_f:396 nb_b:1188 tri:1 dim:3
#                  Attributes on vertices: point[3]
#                  Loading file stls/aqueduct.stl...
#                  (FP64) nb_v:1188 nb_e:0 nb_f:396 nb_b:1188 tri:1 dim:3
#                  Attributes on vertices: point[3]
#                  Loading file stls/ventricle.stl...
#                  (FP64) nb_v:5040 nb_e:0 nb_f:1680 nb_b:5040 tri:1 dim:3
#                  Attributes on vertices: point[3]
# bbox_diag_length = 0.318427
# ideal_edge_length = 0.0159214
# stage = 2
# eps_input = 0.000636855
# eps = 0.000352556
# eps_simplification = 0.000282045
# eps_coplanar = 3.18427e-07
# dd = 0.00042457
# dd_simplification = 0.000339656
# [2026-01-27 14:27:51.084] [float-tetwild] [info] remove duplicates:
# [2026-01-27 14:27:51.084] [float-tetwild] [info] #v: 18684 -> 3126
# [2026-01-27 14:27:51.084] [float-tetwild] [info] #f: 6228 -> 6228
# collapsing 0.0902366
# swapping 0.0263373
# [2026-01-27 14:27:51.202] [float-tetwild] [info] remove duplicates:
# [2026-01-27 14:27:51.202] [float-tetwild] [info] #v: 1778 -> 1778
# [2026-01-27 14:27:51.202] [float-tetwild] [info] #f: 3528 -> 3528
# [2026-01-27 14:27:51.202] [float-tetwild] [info] #v = 1778
# [2026-01-27 14:27:51.202] [float-tetwild] [info] #f = 3528
# #boundary_e1 = 12
# #boundary_e2 = 0
# [2026-01-27 14:27:51.205] [float-tetwild] [info] preprocessing 0.122544s
# [2026-01-27 14:27:51.205] [float-tetwild] [info]
# [2026-01-27 14:27:51.225] [float-tetwild] [info] #v = 2840
# [2026-01-27 14:27:51.225] [float-tetwild] [info] #t = 15819
# [2026-01-27 14:27:51.225] [float-tetwild] [info] tetrahedralizing 0.0205958s
# [2026-01-27 14:27:51.225] [float-tetwild] [info]
# [2026-01-27 14:27:51.225] [float-tetwild] [info] triangle insertion start, #f = 3528, #v = 2840, #t = 15819
# [2026-01-27 14:27:51.229] [float-tetwild] [info] matched #f = 2523, uninserted #f = 1005
# FAIL subdivide_tets
# FAIL subdivide_tets
# FAIL subdivide_tets
# FAIL subdivide_tets
# FAIL subdivide_tets
# FAIL subdivide_tets
# FAIL subdivide_tets
# [2026-01-27 14:27:52.107] [float-tetwild] [info] insert_one_triangle * n done, #v = 48907, #t = 263968
# [2026-01-27 14:27:52.107] [float-tetwild] [info] uninserted #f = 7/1005
# [2026-01-27 14:27:52.107] [float-tetwild] [info] total timing: 0s
# [2026-01-27 14:27:52.200] [float-tetwild] [info] pair_track_surface_fs done
# #boundary_e1 = 29
# #boundary_e2 = 0
# [2026-01-27 14:27:52.201] [float-tetwild] [info] find_boundary_edges done
# [2026-01-27 14:27:52.205] [float-tetwild] [info] time1 = 0.00332329
# FAIL subdivide_tets
# FAIL n_f_ids.empty()
# [2026-01-27 14:27:52.218] [float-tetwild] [info] uninsert boundary #e = 2/29
# [2026-01-27 14:27:52.218] [float-tetwild] [info] time2 = 6.66667e-07
# [2026-01-27 14:27:52.218] [float-tetwild] [info] time3 = 0.00514933
# [2026-01-27 14:27:52.218] [float-tetwild] [info] time4 = 0.00629796
# [2026-01-27 14:27:52.218] [float-tetwild] [info] time5 = 0.00157458
# [2026-01-27 14:27:52.218] [float-tetwild] [info] time6 = 1.625e-06
# [2026-01-27 14:27:52.218] [float-tetwild] [info] uninserted #f = 8/1005
# known_surface_fs.size = 0
# known_not_surface_fs.size = 389
# [2026-01-27 14:27:52.502] [float-tetwild] [info] mark_surface_fs done
# [2026-01-27 14:27:52.503] [float-tetwild] [info] #b_edge1 = 29, #b_edges2 = 40
# [2026-01-27 14:27:52.515] [float-tetwild] [info] cutting 1.28941s
# [2026-01-27 14:27:52.515] [float-tetwild] [info]
# initializing...
# edge collapsing...
# fixed 0 tangled element
# success(env) = 37970
# success = 40383(192339)
# success(env) = 1748
# success = 1946(34498)
# success(env) = 407
# success = 455(16601)
# success(env) = 78
# success = 88(10383)
# success(env) = 16
# success = 22(5094)
# success(env) = 6
# success = 8(1522)
# success(env) = 3
# success = 4(828)
# success(env) = 0
# success = 0(281)
# edge collapsing done!
# time = 2.01689s
# #v = 3673
# #t = 21045
# max_energy = 502428
# avg_energy = 2137.65
# [2026-01-27 14:27:54.535] [float-tetwild] [info] triangle insertion start, #f = 3528, #v = 50425, #t = 271349
# [2026-01-27 14:27:54.537] [float-tetwild] [info] matched #f = 3520, uninserted #f = 8
# [2026-01-27 14:27:54.573] [float-tetwild] [info] insert_one_triangle * n done, #v = 52011, #t = 279735
# [2026-01-27 14:27:54.573] [float-tetwild] [info] uninserted #f = 0/8
# [2026-01-27 14:27:54.573] [float-tetwild] [info] total timing: 0s
# [2026-01-27 14:27:54.576] [float-tetwild] [info] pair_track_surface_fs done
# #boundary_e1 = 12
# #boundary_e2 = 0
# [2026-01-27 14:27:54.577] [float-tetwild] [info] find_boundary_edges done
# [2026-01-27 14:27:54.578] [float-tetwild] [info] time1 = 0.000655042
# [2026-01-27 14:27:54.578] [float-tetwild] [info] uninsert boundary #e = 0/1
# [2026-01-27 14:27:54.578] [float-tetwild] [info] time2 = 0
# [2026-01-27 14:27:54.578] [float-tetwild] [info] time3 = 0.000306375
# [2026-01-27 14:27:54.578] [float-tetwild] [info] time4 = 2.10417e-05
# [2026-01-27 14:27:54.578] [float-tetwild] [info] time5 = 9.58333e-06
# [2026-01-27 14:27:54.578] [float-tetwild] [info] time6 = 0
# [2026-01-27 14:27:54.578] [float-tetwild] [info] uninserted #f = 0/8
# known_surface_fs.size = 0
# known_not_surface_fs.size = 0
# [2026-01-27 14:27:54.589] [float-tetwild] [info] mark_surface_fs done
# [2026-01-27 14:27:54.589] [float-tetwild] [info] #b_edge1 = 12, #b_edges2 = 0
# initializing...
# //////////////// pass 0 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 8236(8236)
# edge splitting done!
# time = 0.034708s
# #v = 13389
# #t = 71643
# max_energy = 1.54686e+07
# avg_energy = 1010.06
# edge collapsing...
# fixed 0 tangled element
# success(env) = 1392
# success = 7733(49167)
# success(env) = 107
# success = 360(20777)
# success(env) = 19
# success = 38(8221)
# success(env) = 8
# success = 21(1836)
# success(env) = 2
# success = 2(963)
# success(env) = 0
# success = 0(157)
# edge collapsing done!
# time = 0.367066s
# #v = 5235
# #t = 28041
# max_energy = 502428
# avg_energy = 1584.23
# edge swapping...
# fixed 0 tangled element
# success3 = 1485
# success4 = 2366
# success5 = 287
# success = 4138(22749)
# edge swapping done!
# time = 0.127043s
# #v = 5235
# #t = 26843
# max_energy = 159532
# avg_energy = 39.3967
# vertex smoothing...
# success = 2723(4063)
# vertex smoothing done!
# time = 0.0303185s
# #v = 5235
# #t = 26843
# max_energy = 159532
# avg_energy = 33.399
# //////////////// pass 1 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 3488(3488)
# edge splitting done!
# time = 0.0227207s
# #v = 8723
# #t = 42749
# max_energy = 159532
# avg_energy = 22.5562
# edge collapsing...
# fixed 0 tangled element
# success(env) = 233
# success = 3430(32642)
# success(env) = 39
# success = 128(14008)
# success(env) = 10
# success = 15(3440)
# success(env) = 0
# success = 2(951)
# success(env) = 0
# success = 0(51)
# edge collapsing done!
# time = 0.222719s
# #v = 5148
# #t = 26434
# max_energy = 159532
# avg_energy = 32.2479
# edge swapping...
# fixed 0 tangled element
# success3 = 141
# success4 = 803
# success5 = 47
# success = 991(16601)
# edge swapping done!
# time = 0.0952966s
# #v = 5148
# #t = 26340
# max_energy = 138505
# avg_energy = 18.9254
# vertex smoothing...
# success = 2721(3988)
# vertex smoothing done!
# time = 0.0257591s
# #v = 5148
# #t = 26340
# max_energy = 138505
# avg_energy = 18.822
# //////////////// pass 2 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 2901(2901)
# edge splitting done!
# time = 0.0210988s
# #v = 8049
# #t = 38897
# max_energy = 138505
# avg_energy = 14.1061
# edge collapsing...
# fixed 0 tangled element
# success(env) = 35
# success = 2698(30244)
# success(env) = 2
# success = 76(9536)
# success(env) = 0
# success = 3(837)
# success(env) = 0
# success = 1(14)
# success(env) = 0
# success = 0(13)
# edge collapsing done!
# time = 0.156024s
# #v = 5271
# #t = 26926
# max_energy = 138505
# avg_energy = 18.4963
# edge swapping...
# fixed 0 tangled element
# success3 = 36
# success4 = 479
# success5 = 25
# success = 540(16363)
# edge swapping done!
# time = 0.0879417s
# #v = 5271
# #t = 26915
# max_energy = 138505
# avg_energy = 16.7948
# vertex smoothing...
# success = 2736(4078)
# vertex smoothing done!
# time = 0.027601s
# #v = 5271
# #t = 26915
# max_energy = 138505
# avg_energy = 16.7466
# //////////////// pass 3 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 2677(2677)
# edge splitting done!
# time = 0.0216336s
# #v = 7948
# #t = 38375
# max_energy = 138505
# avg_energy = 13.002
# edge collapsing...
# fixed 0 tangled element
# success(env) = 21
# success = 2495(30020)
# success(env) = 1
# success = 58(7237)
# success(env) = 0
# success = 5(631)
# success(env) = 0
# success = 0(64)
# edge collapsing done!
# time = 0.143215s
# #v = 5390
# #t = 27507
# max_energy = 138505
# avg_energy = 16.4759
# edge swapping...
# fixed 0 tangled element
# success3 = 37
# success4 = 333
# success5 = 13
# success = 383(16630)
# edge swapping done!
# time = 0.0827117s
# #v = 5390
# #t = 27483
# max_energy = 138505
# avg_energy = 16.4739
# vertex smoothing...
# success = 2699(4142)
# vertex smoothing done!
# time = 0.0248625s
# #v = 5390
# #t = 27483
# max_energy = 138505
# avg_energy = 16.4442
# updating sclaing field ...
# filter_energy = 100
# is_hit_min_edge_length = 0
# enlarge envelope, eps = 0.000391729
# //////////////// pass 4 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 2815(2815)
# edge splitting done!
# time = 0.0213701s
# #v = 8205
# #t = 39644
# max_energy = 123068
# avg_energy = 47.6105
# edge collapsing...
# fixed 0 tangled element
# success(env) = 96
# success = 2680(28956)
# success(env) = 4
# success = 66(8712)
# success(env) = 1
# success = 4(437)
# success(env) = 0
# success = 0(23)
# edge collapsing done!
# time = 0.152775s
# #v = 5455
# #t = 27873
# max_energy = 32.5443
# avg_energy = 3.86928
# edge swapping...
# fixed 0 tangled element
# success3 = 29
# success4 = 377
# success5 = 16
# success = 422(17165)
# edge swapping done!
# time = 0.0849303s
# #v = 5455
# #t = 27860
# max_energy = 32.5443
# avg_energy = 3.8563
# vertex smoothing...
# success = 2848(4194)
# vertex smoothing done!
# time = 0.0258842s
# #v = 5455
# #t = 27860
# max_energy = 29.0186
# avg_energy = 3.82278
# //////////////// pass 5 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 2550(2550)
# edge splitting done!
# time = 0.0216418s
# #v = 8005
# #t = 38529
# max_energy = 29.0186
# avg_energy = 3.92657
# edge collapsing...
# fixed 0 tangled element
# success(env) = 39
# success = 2441(28143)
# success(env) = 0
# success = 57(6499)
# success(env) = 0
# success = 2(229)
# success(env) = 0
# success = 0(11)
# edge collapsing done!
# time = 0.133904s
# #v = 5505
# #t = 28146
# max_energy = 29.0186
# avg_energy = 3.8303
# edge swapping...
# fixed 0 tangled element
# success3 = 21
# success4 = 288
# success5 = 13
# success = 322(17406)
# edge swapping done!
# time = 0.0799281s
# #v = 5505
# #t = 28138
# max_energy = 29.0186
# avg_energy = 3.82169
# vertex smoothing...
# success = 2817(4230)
# vertex smoothing done!
# time = 0.0259771s
# #v = 5505
# #t = 28138
# max_energy = 28.2088
# avg_energy = 3.80207
# //////////////// pass 6 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 2437(2437)
# edge splitting done!
# time = 0.0216262s
# #v = 7942
# #t = 38176
# max_energy = 28.2088
# avg_energy = 3.90353
# edge collapsing...
# fixed 0 tangled element
# success(env) = 30
# success = 2335(27974)
# success(env) = 1
# success = 54(5949)
# success(env) = 0
# success = 1(315)
# success(env) = 0
# success = 1(6)
# success(env) = 0
# success = 0(7)
# edge collapsing done!
# time = 0.128413s
# #v = 5551
# #t = 28359
# max_energy = 28.2088
# avg_energy = 3.81258
# edge swapping...
# fixed 0 tangled element
# success3 = 13
# success4 = 228
# success5 = 5
# success = 246(17534)
# edge swapping done!
# time = 0.0797623s
# #v = 5551
# #t = 28351
# max_energy = 28.2088
# avg_energy = 3.8066
# vertex smoothing...
# success = 2727(4254)
# vertex smoothing done!
# time = 0.0227919s
# #v = 5551
# #t = 28351
# max_energy = 28.2088
# avg_energy = 3.79127
# updating sclaing field ...
# filter_energy = 8
# is_hit_min_edge_length = 0
# //////////////// pass 7 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 4042(4042)
# edge splitting done!
# time = 0.0251605s
# #v = 9593
# #t = 46946
# max_energy = 29.5661
# avg_energy = 4.03719
# edge collapsing...
# fixed 0 tangled element
# success(env) = 193
# success = 3234(31224)
# success(env) = 16
# success = 124(11109)
# success(env) = 0
# success = 7(1915)
# success(env) = 1
# success = 1(134)
# success(env) = 0
# success = 0(18)
# edge collapsing done!
# time = 0.176779s
# #v = 6227
# #t = 32183
# max_energy = 20.0637
# avg_energy = 3.81223
# edge swapping...
# fixed 0 tangled element
# success3 = 79
# success4 = 628
# success5 = 38
# success = 745(21454)
# edge swapping done!
# time = 0.128434s
# #v = 6227
# #t = 32142
# max_energy = 20.0637
# avg_energy = 3.77614
# vertex smoothing...
# success = 3460(4917)
# vertex smoothing done!
# time = 0.0290212s
# #v = 6227
# #t = 32142
# max_energy = 20.0637
# avg_energy = 3.71383
# //////////////// pass 8 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 2648(2648)
# edge splitting done!
# time = 0.0240655s
# #v = 8875
# #t = 43237
# max_energy = 20.0637
# avg_energy = 3.84081
# edge collapsing...
# fixed 0 tangled element
# success(env) = 112
# success = 2531(28425)
# success(env) = 4
# success = 69(8639)
# success(env) = 0
# success = 1(762)
# success(env) = 0
# success = 0(7)
# edge collapsing done!
# time = 0.140755s
# #v = 6274
# #t = 32366
# max_energy = 20.0637
# avg_energy = 3.7219
# edge swapping...
# fixed 0 tangled element
# success3 = 25
# success4 = 380
# success5 = 21
# success = 426(21193)
# edge swapping done!
# time = 0.0995972s
# #v = 6274
# #t = 32362
# max_energy = 20.0637
# avg_energy = 3.7133
# vertex smoothing...
# success = 3411(4918)
# vertex smoothing done!
# time = 0.0260228s
# #v = 6274
# #t = 32362
# max_energy = 20.0637
# avg_energy = 3.68209
# updating sclaing field ...
# filter_energy = 8
# is_hit_min_edge_length = 0
# //////////////// pass 9 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 3218(3218)
# edge splitting done!
# time = 0.0253923s
# #v = 9492
# #t = 46770
# max_energy = 22.2316
# avg_energy = 3.90487
# edge collapsing...
# fixed 0 tangled element
# success(env) = 193
# success = 2676(36137)
# success(env) = 16
# success = 98(10683)
# success(env) = 0
# success = 5(1314)
# success(env) = 0
# success = 1(149)
# success(env) = 0
# success = 0(53)
# edge collapsing done!
# time = 0.172402s
# #v = 6712
# #t = 34870
# max_energy = 9.12711
# avg_energy = 3.7145
# edge swapping...
# fixed 0 tangled element
# success3 = 44
# success4 = 501
# success5 = 31
# success = 576(23351)
# edge swapping done!
# time = 0.120716s
# #v = 6712
# #t = 34857
# max_energy = 7.44614
# avg_energy = 3.69798
# vertex smoothing...
# success = 3769(5330)
# vertex smoothing done!
# time = 0.0283661s
# #v = 6712
# #t = 34857
# max_energy = 7.27836
# avg_energy = 3.65548
# //////////////// postprocessing ////////////////
# edge collapsing...
# fixed 0 tangled element
# success(env) = 26
# success = 157(37522)
# success(env) = 5
# success = 14(6895)
# success(env) = 2
# success = 5(1209)
# success(env) = 0
# success = 2(220)
# success(env) = 0
# success = 1(179)
# success(env) = 0
# success = 0(155)
# edge collapsing done!
# time = 0.120789s
# #v = 6533
# #t = 33974
# max_energy = 7.27836
# avg_energy = 3.65128
# [2026-01-27 14:27:58.046] [float-tetwild] [info] mesh optimization 5.52905s
# [2026-01-27 14:27:58.046] [float-tetwild] [info]
# [2026-01-27 14:27:58.058] [float-tetwild] [info] correct_tracked_surface_orientation done
# [2026-01-27 14:27:58.119] [float-tetwild] [info] after winding number
# [2026-01-27 14:27:58.119] [float-tetwild] [info] #v = 6533
# [2026-01-27 14:27:58.120] [float-tetwild] [info] #t = 16300
# [2026-01-27 14:27:58.120] [float-tetwild] [info] winding number 1.56576e+06s
# [2026-01-27 14:27:58.120] [float-tetwild] [info]

# %% [markdown]
# Next we check the *marker* values returned by *fTetWild* and set our own subdomain ids and write the mesh to file:

# %%
subdomains = np.copy(marker)
subdomains[np.isin(marker, [1,2])] = 1
subdomains[np.isin(marker, [3,4])] = 2 # parenchyma parts
subdomains[np.isin(marker, [5])] = 4
subdomains[np.isin(marker, [6])] = 5
labels = np.copy(subdomains) # ftetwild labels 1-5
subdomains[np.isin(subdomains, [2])] = 100 # tmp to avoid conflict
subdomains[np.isin(subdomains, [1,3,4,5])] = fluid_id
subdomains[np.isin(subdomains, [100])] = porous_id
meshio_mesh = meshio.Mesh(point_array, [("tetra", cell_array)],
                       cell_data={#"gmsh:physical": [marker.ravel()],
                                  "ftetwild_labels": [labels.ravel()],
                                  "labels": [subdomains.ravel()]})
meshio_mesh.write("mesh/idealized.xdmf")

# %% [markdown]
# Finally, we check the resulting mesh by reading it back in and plotting it:

# %%
pv_mesh = pv.read_meshio("mesh/idealized.xdmf").clean() # changed from pv.read to pv.read_meshio
pv_mesh.clip(normal=(1,0,0),crinkle=True).plot(show_edges=True, background="white")
# Out:
# /Users/ingvildsd/miniforge3/envs/brainpulse_new/lib/python3.13/site-packages/pyvista/jupyter/notebook.py:56: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %% [markdown]
# ### Generating subdomain restrictions for Multiphenics
#
# To create function spaces restricted to a subdomain of the whole mesh with *MultiPhenics*, we need to create and save so-called *MeshRestrictions* prior to the main simulation run:

# %%
from fenics import *
from multiphenics import *

def generate_subdomain_restriction(mesh, subdomains, subdomain_id):
    D = mesh.topology().dim()
    # Initialize empty restriction
    restriction = MeshRestriction(mesh, None)
    for d in range(D + 1):
        mesh_function_d = MeshFunction("bool", mesh, d)
        mesh_function_d.set_all(False)
        restriction.append(mesh_function_d)
    # Mark restriction mesh functions based on subdomain id
    for c in cells(mesh):
        if subdomains[c] == subdomain_id:
            restriction[D][c] = True
            for d in range(D):
                for e in entities(c, d):
                    restriction[d][e] = True
    # Return
    return restriction

# %%
fenics_mesh = Mesh()
with XDMFFile("mesh/idealized.xdmf") as f:
    f.read(fenics_mesh)
    sm = MeshFunction("size_t", fenics_mesh, 3, 0)
    labels = MeshFunction("size_t", fenics_mesh, 3, 0)
    f.read(sm, "labels") # fluid and porous subdomains
    f.read(labels, "ftetwild_labels") # ftetwild labels 1-5
    #sm.rename("subdomains","labels")
    #labels.rename("labels", "ftetwild_labels")

fluid_restr = generate_subdomain_restriction(fenics_mesh, sm, fluid_id)
porous_restr = generate_subdomain_restriction(fenics_mesh, sm, porous_id)
fluid_restr._write("mesh/idealized_fluid.rtc.xdmf")
porous_restr._write("mesh/idealized_porous.rtc.xdmf")

# %% [markdown]
# ## Marking Boundaries and Interfaces
# We mark both the internal interface by looping over all facets in the mesh, checking the subdomain ids of the corresponding cells and identifying the internal interfaces.
# In addition to the tissue-CSF interface, we also mark the surface between the aqueduct and the fourth ventricle, since we would like to compute aqueduct flow rates in the post-processing step.

# %%
bm = MeshFunction("size_t", fenics_mesh, 2, 0)

def mark_internal_interface(mesh, subdomains, bm, interface_id,
                            doms=None):
    # set internal interface
    for f in facets(mesh):
        domains = []
        for c in cells(f):
            domains.append(subdomains[c])
        domains = set(domains)
        if len(domains)==2:
            if doms is None:
                bm[f] = interface_id
            elif set(doms)==domains:
                bm[f] = interface_id

# mark tissue-CSF interface
mark_internal_interface(fenics_mesh, sm, bm, interface_id)
# mark aqueduct-fourth ventricle interface for later flow computation
mark_internal_interface(fenics_mesh, labels, bm, aqueduct_V4_id, doms=[4,5])

# %% [markdown]
# Similarly, we mark the external boundaries by a combination of the facet location and the subdomain id of the corresponding subdomain:

# %%
def mark_external_boundaries(mesh, subdomains, boundaries, 
                             subdomain_ids, new_boundary_id):
    for f in facets(mesh):
        if not f.exterior():
            continue
        c = list(cells(f))[0]
        if subdomains[c] in subdomain_ids:
            boundaries[f] = new_boundary_id
                
z_min = fenics_mesh.coordinates()[:,2].min()
bottom = CompiledSubDomain("on_boundary && near(x[2], v, tol)",
                        v=z_min, tol=0.001)
outer = CompiledSubDomain("on_boundary")
outer.mark(bm, skull_id)
bottom.mark(bm, spinal_canal_id)
mark_external_boundaries(fenics_mesh, sm, bm, 
                         [porous_id], spinal_cord_id)

with XDMFFile("mesh/idealized_boundaries.xdmf") as f:
    f.write(bm)
#with XDMFFile("mesh/idealized.xdmf") as f:
#    f.write(sm)
