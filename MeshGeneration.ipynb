# %% [markdown]
# ### Multidomain Mesh Generation with fTetWild
#
# In this notebook, we demonstrate how to generate a multidomain idealized brain mesh using boolean operations on surface meshes (STLs) with [fTetWild](https://wildmeshing.github.io/ftetwild/).
#
# First, we import the relevant packages and set the ids of the subdomains and boundaries we want to mark:

# %%
import wildmeshing as wm
import pyvista as pv
import numpy as np
import meshio
import json
from pathlib import Path

# domain ids
porous_id = 1
fluid_id = 2

# facet ids
#skull_id = 1
#spinal_canal_id = 2
#interface_id = 3
#spinal_cord_id = 4
#aqueduct_V4_id = 5

interface_id = 1
skull_id = 2
spinal_canal_id = 3
spinal_cord_id = 4
aqueduct_V4_id = 5

# %% [markdown]
# As our geometry consists of multiple spheres and cylinders, we create surface meshes for each of the components with PyVista and plot them to check the setup:

# %%
skull = pv.Sphere(radius = 0.08)
parenchyma = pv.Sphere(radius = 0.07)
ventricle = pv.Sphere(radius = 0.02)
canal = pv.Cylinder(center=(0, 0, -0.105), direction=(0,0,-1),
                        radius=0.025, height=0.08).triangulate()
cord = pv.Cylinder(center=(0, 0, -0.105), direction=(0,0,-1),
                        radius=0.017, height=0.08).triangulate()
aqueduct = pv.Cylinder(center=(0, 0.03, -0.03), direction=(0,1,-1),
                       radius=0.004, height=0.06).triangulate()

# display the geometry using PyVista
pl = pv.Plotter()
pl.add_mesh(parenchyma, opacity=.6, color="blue")
pl.add_mesh(ventricle,  color="red")
pl.add_mesh(aqueduct, opacity=0.7, color="red")
pl.add_mesh(skull, opacity=0.2)
pl.add_mesh(canal, opacity=0.2)
pl.add_mesh(cord, opacity=0.7, color="blue")
pl.background_color = "white"
pl.show()
# Out:
# /Users/ingvildsd/miniforge3/envs/brainpulse_new/lib/python3.13/site-packages/pyvista/jupyter/notebook.py:56: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
# save the surface meshes for later use by fTetWild
stl_directory = Path("stls/")
stl_directory.mkdir(exist_ok=True, parents=True)
parenchyma.save(stl_directory / "parenchyma.stl")
skull.save(stl_directory / "skull.stl")
cord.save(stl_directory / "cord.stl")
canal.save(stl_directory / "canal.stl")
ventricle.save(stl_directory / "ventricle.stl")
aqueduct.save(stl_directory / "aqueduct.stl")

# %% [markdown]
# Now, we have everything in place to define a constructive solid geometry(CSG)-tree, describing the order and type of boolean operations carried out on the surface meshes:
#
# * first, we take the union of brain tissue components: parenchyma and spinal cord
# * then, we subtract the ventricle and aqueduct parts from the tissue
# * finally, we take the union of the outermost sphere and cylinder with the result of the previous steps
#
# Further, we specify maximum distance between the input surfaces and the surface of the generated volumetric mesh with the *epsilon* parameter (specifying the relative envelop size) and relative edge length with *edge_length_r*.
#
# Note that while we use a simple geometry here, we can easily replace the STL files with complex shapes and apply the same procedure to generate image-derived realistic models.

# %%
tetra = wm.Tetrahedralizer(epsilon=0.002, edge_length_r=0.05,
                           coarsen=False)
tetra.load_csg_tree(json.dumps(
    {"operation":"union",
     "right":
          {
          "operation":"difference",
          "left":{"operation":"union", "left": str(stl_directory / "parenchyma.stl"),
                              "right": str(stl_directory / "cord.stl")},
          "right":{"operation":"union", "left": str(stl_directory / "aqueduct.stl"),
                          "right":str(stl_directory / "ventricle.stl")},
          },
     "left":
        {"operation":"union", "left": str(stl_directory / "skull.stl"),
                          "right":str(stl_directory / "canal.stl")},                
    }
))
tetra.tetrahedralize()
point_array, cell_array, marker = tetra.get_tet_mesh()
# Out:
# TBB threads 12
#                  Loading file stls/skull.stl...
#                  (FP64) nb_v:5040 nb_e:0 nb_f:1680 nb_b:5040 tri:1 dim:3
#                  Attributes on vertices: point[3]
#                  Loading file stls/canal.stl...
#                  (FP64) nb_v:1188 nb_e:0 nb_f:396 nb_b:1188 tri:1 dim:3
#                  Attributes on vertices: point[3]
#                  Loading file stls/parenchyma.stl...
#                  (FP64) nb_v:5040 nb_e:0 nb_f:1680 nb_b:5040 tri:1 dim:3
#                  Attributes on vertices: point[3]
#                  Loading file stls/cord.stl...
#                  (FP64) nb_v:1188 nb_e:0 nb_f:396 nb_b:1188 tri:1 dim:3
#                  Attributes on vertices: point[3]
#                  Loading file stls/aqueduct.stl...
#                  (FP64) nb_v:1188 nb_e:0 nb_f:396 nb_b:1188 tri:1 dim:3
#                  Attributes on vertices: point[3]
#                  Loading file stls/ventricle.stl...
#                  (FP64) nb_v:5040 nb_e:0 nb_f:1680 nb_b:5040 tri:1 dim:3
#                  Attributes on vertices: point[3]
# bbox_diag_length = 0.318427
# ideal_edge_length = 0.0159214
# stage = 2
# eps_input = 0.000636855
# eps = 0.000352556
# eps_simplification = 0.000282045
# eps_coplanar = 3.18427e-07
# dd = 0.00042457
# dd_simplification = 0.000339656
# [2026-01-05 23:03:54.540] [float-tetwild] [info] remove duplicates:
# [2026-01-05 23:03:54.540] [float-tetwild] [info] #v: 18684 -> 3126
# [2026-01-05 23:03:54.540] [float-tetwild] [info] #f: 6228 -> 6228
# collapsing 0.0991743
# swapping 0.0226704
# [2026-01-05 23:03:54.664] [float-tetwild] [info] remove duplicates:
# [2026-01-05 23:03:54.664] [float-tetwild] [info] #v: 1775 -> 1775
# [2026-01-05 23:03:54.664] [float-tetwild] [info] #f: 3522 -> 3522
# [2026-01-05 23:03:54.664] [float-tetwild] [info] #v = 1775
# [2026-01-05 23:03:54.664] [float-tetwild] [info] #f = 3522
# #boundary_e1 = 12
# #boundary_e2 = 0
# [2026-01-05 23:03:54.667] [float-tetwild] [info] preprocessing 0.1283s
# [2026-01-05 23:03:54.667] [float-tetwild] [info]
# [2026-01-05 23:03:54.689] [float-tetwild] [info] #v = 2837
# [2026-01-05 23:03:54.689] [float-tetwild] [info] #t = 15792
# [2026-01-05 23:03:54.689] [float-tetwild] [info] tetrahedralizing 0.0216221s
# [2026-01-05 23:03:54.689] [float-tetwild] [info]
# [2026-01-05 23:03:54.689] [float-tetwild] [info] triangle insertion start, #f = 3522, #v = 2837, #t = 15792
# [2026-01-05 23:03:54.692] [float-tetwild] [info] matched #f = 2554, uninserted #f = 968
# FAIL subdivide_tets
# FAIL subdivide_tets
# FAIL subdivide_tets
# FAIL subdivide_tets
# FAIL subdivide_tets
# FAIL subdivide_tets
# FAIL subdivide_tets
# [2026-01-05 23:03:55.488] [float-tetwild] [info] insert_one_triangle * n done, #v = 42952, #t = 232734
# [2026-01-05 23:03:55.488] [float-tetwild] [info] uninserted #f = 7/968
# [2026-01-05 23:03:55.488] [float-tetwild] [info] total timing: 0s
# [2026-01-05 23:03:55.567] [float-tetwild] [info] pair_track_surface_fs done
# #boundary_e1 = 33
# #boundary_e2 = 0
# [2026-01-05 23:03:55.568] [float-tetwild] [info] find_boundary_edges done
# [2026-01-05 23:03:55.571] [float-tetwild] [info] time1 = 0.00280267
# [2026-01-05 23:03:55.577] [float-tetwild] [info] uninsert boundary #e = 0/33
# [2026-01-05 23:03:55.577] [float-tetwild] [info] time2 = 7.91667e-07
# [2026-01-05 23:03:55.577] [float-tetwild] [info] time3 = 0.00240675
# [2026-01-05 23:03:55.577] [float-tetwild] [info] time4 = 0.00224675
# [2026-01-05 23:03:55.577] [float-tetwild] [info] time5 = 0.000668292
# [2026-01-05 23:03:55.577] [float-tetwild] [info] time6 = 8.75e-07
# [2026-01-05 23:03:55.577] [float-tetwild] [info] uninserted #f = 7/968
# known_surface_fs.size = 0
# known_not_surface_fs.size = 0
# [2026-01-05 23:03:55.846] [float-tetwild] [info] mark_surface_fs done
# [2026-01-05 23:03:55.846] [float-tetwild] [info] #b_edge1 = 33, #b_edges2 = 0
# [2026-01-05 23:03:55.857] [float-tetwild] [info] cutting 1.16859s
# [2026-01-05 23:03:55.857] [float-tetwild] [info]
# initializing...
# edge collapsing...
# fixed 0 tangled element
# success(env) = 31297
# success = 33223(173823)
# success(env) = 1724
# success = 1898(31134)
# success(env) = 272
# success = 308(14254)
# success(env) = 68
# success = 75(8594)
# success(env) = 15
# success = 16(3539)
# success(env) = 3
# success = 5(792)
# success(env) = 1
# success = 1(374)
# success(env) = 1
# success = 1(81)
# success(env) = 0
# success = 0(151)
# edge collapsing done!
# time = 1.84955s
# #v = 3557
# #t = 20375
# max_energy = 502428
# avg_energy = 2214.1
# [2026-01-05 23:03:57.710] [float-tetwild] [info] triangle insertion start, #f = 3522, #v = 43550, #t = 235673
# [2026-01-05 23:03:57.711] [float-tetwild] [info] matched #f = 3515, uninserted #f = 7
# [2026-01-05 23:03:57.729] [float-tetwild] [info] insert_one_triangle * n done, #v = 43948, #t = 237761
# [2026-01-05 23:03:57.729] [float-tetwild] [info] uninserted #f = 0/7
# [2026-01-05 23:03:57.729] [float-tetwild] [info] total timing: 0s
# [2026-01-05 23:03:57.730] [float-tetwild] [info] pair_track_surface_fs done
# #boundary_e1 = 12
# #boundary_e2 = 0
# [2026-01-05 23:03:57.731] [float-tetwild] [info] find_boundary_edges done
# [2026-01-05 23:03:57.732] [float-tetwild] [info] time1 = 0.000526792
# [2026-01-05 23:03:57.732] [float-tetwild] [info] uninsert boundary #e = 0/0
# [2026-01-05 23:03:57.732] [float-tetwild] [info] time2 = 0
# [2026-01-05 23:03:57.732] [float-tetwild] [info] time3 = 0
# [2026-01-05 23:03:57.732] [float-tetwild] [info] time4 = 0
# [2026-01-05 23:03:57.732] [float-tetwild] [info] time5 = 0
# [2026-01-05 23:03:57.732] [float-tetwild] [info] time6 = 0
# [2026-01-05 23:03:57.732] [float-tetwild] [info] uninserted #f = 0/7
# known_surface_fs.size = 0
# known_not_surface_fs.size = 0
# [2026-01-05 23:03:57.737] [float-tetwild] [info] mark_surface_fs done
# [2026-01-05 23:03:57.737] [float-tetwild] [info] #b_edge1 = 12, #b_edges2 = 0
# initializing...
# //////////////// pass 0 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 8355(8355)
# edge splitting done!
# time = 0.0336901s
# #v = 12273
# #t = 65716
# max_energy = 2.32807e+06
# avg_energy = 866.816
# edge collapsing...
# fixed 0 tangled element
# success(env) = 433
# success = 6752(44367)
# success(env) = 59
# success = 310(19948)
# success(env) = 13
# success = 48(7261)
# success(env) = 3
# success = 11(1912)
# success(env) = 6
# success = 9(800)
# success(env) = 3
# success = 4(592)
# success(env) = 1
# success = 1(410)
# success(env) = 0
# success = 0(85)
# edge collapsing done!
# time = 0.326757s
# #v = 5138
# #t = 27610
# max_energy = 502428
# avg_energy = 1610.98
# edge swapping...
# fixed 0 tangled element
# success3 = 1565
# success4 = 2347
# success5 = 281
# success = 4193(22839)
# edge swapping done!
# time = 0.123269s
# #v = 5138
# #t = 26326
# max_energy = 350213
# avg_energy = 32.36
# vertex smoothing...
# success = 2698(3979)
# vertex smoothing done!
# time = 0.0286177s
# #v = 5138
# #t = 26326
# max_energy = 350213
# avg_energy = 31.6683
# //////////////// pass 1 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 3518(3518)
# edge splitting done!
# time = 0.0254468s
# #v = 8656
# #t = 42321
# max_energy = 350213
# avg_energy = 21.307
# edge collapsing...
# fixed 0 tangled element
# success(env) = 218
# success = 3357(31742)
# success(env) = 19
# success = 93(14491)
# success(env) = 2
# success = 6(2049)
# success(env) = 1
# success = 3(348)
# success(env) = 4
# success = 4(451)
# success(env) = 1
# success = 1(284)
# success(env) = 0
# success = 0(68)
# edge collapsing done!
# time = 0.222891s
# #v = 5192
# #t = 26660
# max_energy = 350213
# avg_energy = 30.5483
# edge swapping...
# fixed 0 tangled element
# success3 = 132
# success4 = 910
# success5 = 60
# success = 1102(17117)
# edge swapping done!
# time = 0.100149s
# #v = 5192
# #t = 26588
# max_energy = 350213
# avg_energy = 24.7752
# vertex smoothing...
# success = 2771(4041)
# vertex smoothing done!
# time = 0.026785s
# #v = 5192
# #t = 26588
# max_energy = 350213
# avg_energy = 24.6782
# //////////////// pass 2 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 2791(2791)
# edge splitting done!
# time = 0.023356s
# #v = 7983
# #t = 38594
# max_energy = 350213
# avg_energy = 18.3127
# edge collapsing...
# fixed 0 tangled element
# success(env) = 31
# success = 2588(29871)
# success(env) = 1
# success = 41(8640)
# success(env) = 0
# success = 0(606)
# edge collapsing done!
# time = 0.150075s
# #v = 5354
# #t = 27379
# max_energy = 350213
# avg_energy = 24.0855
# edge swapping...
# fixed 0 tangled element
# success3 = 57
# success4 = 494
# success5 = 27
# success = 578(16945)
# edge swapping done!
# time = 0.087996s
# #v = 5354
# #t = 27349
# max_energy = 350213
# avg_energy = 22.3307
# vertex smoothing...
# success = 2779(4135)
# vertex smoothing done!
# time = 0.0247393s
# #v = 5354
# #t = 27349
# max_energy = 350213
# avg_energy = 22.2821
# updating sclaing field ...
# filter_energy = 100
# is_hit_min_edge_length = 0
# enlarge envelope, eps = 0.000391729
# //////////////// pass 3 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 3082(3082)
# edge splitting done!
# time = 0.024219s
# #v = 8436
# #t = 40869
# max_energy = 299158
# avg_energy = 71.7911
# edge collapsing...
# fixed 0 tangled element
# success(env) = 114
# success = 2777(30969)
# success(env) = 18
# success = 88(10642)
# success(env) = 4
# success = 9(1348)
# success(env) = 0
# success = 1(218)
# success(env) = 0
# success = 0(25)
# edge collapsing done!
# time = 0.168115s
# #v = 5561
# #t = 28426
# max_energy = 64.7008
# avg_energy = 3.89026
# edge swapping...
# fixed 0 tangled element
# success3 = 36
# success4 = 473
# success5 = 27
# success = 536(17863)
# edge swapping done!
# time = 0.0898598s
# #v = 5561
# #t = 28417
# max_energy = 64.7008
# avg_energy = 3.875
# vertex smoothing...
# success = 3013(4314)
# vertex smoothing done!
# time = 0.025726s
# #v = 5561
# #t = 28417
# max_energy = 64.7008
# avg_energy = 3.83043
# //////////////// pass 4 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 2585(2585)
# edge splitting done!
# time = 0.023247s
# #v = 8146
# #t = 39286
# max_energy = 64.7008
# avg_energy = 3.93413
# edge collapsing...
# fixed 0 tangled element
# success(env) = 54
# success = 2484(29693)
# success(env) = 2
# success = 61(7088)
# success(env) = 0
# success = 7(536)
# success(env) = 0
# success = 0(127)
# edge collapsing done!
# time = 0.140007s
# #v = 5594
# #t = 28578
# max_energy = 64.7008
# avg_energy = 3.84339
# edge swapping...
# fixed 0 tangled element
# success3 = 34
# success4 = 378
# success5 = 12
# success = 424(17944)
# edge swapping done!
# time = 0.0829228s
# #v = 5594
# #t = 28556
# max_energy = 64.7008
# avg_energy = 3.83407
# vertex smoothing...
# success = 2912(4305)
# vertex smoothing done!
# time = 0.0246369s
# #v = 5594
# #t = 28556
# max_energy = 64.7008
# avg_energy = 3.80573
# updating sclaing field ...
# filter_energy = 8
# is_hit_min_edge_length = 0
# //////////////// pass 5 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 4016(4016)
# edge splitting done!
# time = 0.0274872s
# #v = 9610
# #t = 47046
# max_energy = 61.3379
# avg_energy = 4.03612
# edge collapsing...
# fixed 0 tangled element
# success(env) = 180
# success = 3207(32648)
# success(env) = 18
# success = 136(11886)
# success(env) = 2
# success = 16(1880)
# success(env) = 1
# success = 3(254)
# success(env) = 0
# success = 0(70)
# edge collapsing done!
# time = 0.194122s
# #v = 6248
# #t = 32267
# max_energy = 61.3379
# avg_energy = 3.82476
# edge swapping...
# fixed 0 tangled element
# success3 = 76
# success4 = 583
# success5 = 41
# success = 700(21399)
# edge swapping done!
# time = 0.123298s
# #v = 6248
# #t = 32232
# max_energy = 61.3379
# avg_energy = 3.79796
# vertex smoothing...
# success = 3553(4920)
# vertex smoothing done!
# time = 0.0286403s
# #v = 6248
# #t = 32232
# max_energy = 61.3379
# avg_energy = 3.7379
# //////////////// pass 6 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 2735(2735)
# edge splitting done!
# time = 0.0264591s
# #v = 8983
# #t = 43836
# max_energy = 61.3379
# avg_energy = 3.86535
# edge collapsing...
# fixed 0 tangled element
# success(env) = 93
# success = 2598(30005)
# success(env) = 2
# success = 63(9291)
# success(env) = 0
# success = 6(629)
# success(env) = 0
# success = 0(100)
# edge collapsing done!
# time = 0.156831s
# #v = 6316
# #t = 32592
# max_energy = 61.3379
# avg_energy = 3.75065
# edge swapping...
# fixed 0 tangled element
# success3 = 25
# success4 = 395
# success5 = 15
# success = 435(21234)
# edge swapping done!
# time = 0.104753s
# #v = 6316
# #t = 32582
# max_energy = 61.3379
# avg_energy = 3.74101
# vertex smoothing...
# success = 3517(4978)
# vertex smoothing done!
# time = 0.0277342s
# #v = 6316
# #t = 32582
# max_energy = 61.3379
# avg_energy = 3.71098
# updating sclaing field ...
# filter_energy = 8
# is_hit_min_edge_length = 0
# //////////////// pass 7 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 3995(3995)
# edge splitting done!
# time = 0.0300089s
# #v = 10311
# #t = 51103
# max_energy = 45.8207
# avg_energy = 3.98564
# edge collapsing...
# fixed 0 tangled element
# success(env) = 259
# success = 3090(39508)
# success(env) = 25
# success = 142(12099)
# success(env) = 2
# success = 11(1873)
# success(env) = 1
# success = 2(193)
# success(env) = 0
# success = 0(21)
# edge collapsing done!
# time = 0.195581s
# #v = 7066
# #t = 36869
# max_energy = 12.6037
# avg_energy = 3.74968
# edge swapping...
# fixed 0 tangled element
# success3 = 58
# success4 = 618
# success5 = 36
# success = 712(24904)
# edge swapping done!
# time = 0.143841s
# #v = 7066
# #t = 36847
# max_energy = 12.6037
# avg_energy = 3.72513
# vertex smoothing...
# success = 4139(5676)
# vertex smoothing done!
# time = 0.0314842s
# #v = 7066
# #t = 36847
# max_energy = 8.49962
# avg_energy = 3.66681
# //////////////// postprocessing ////////////////
# edge collapsing...
# fixed 0 tangled element
# success(env) = 41
# success = 162(42218)
# success(env) = 3
# success = 18(8512)
# success(env) = 0
# success = 3(903)
# success(env) = 0
# success = 0(181)
# edge collapsing done!
# time = 0.137017s
# #v = 6883
# #t = 35921
# max_energy = 8.49962
# avg_energy = 3.66198
# [2026-01-05 23:04:00.752] [float-tetwild] [info] mesh optimization 4.89332s
# [2026-01-05 23:04:00.752] [float-tetwild] [info]
# [2026-01-05 23:04:00.765] [float-tetwild] [info] correct_tracked_surface_orientation done
# [2026-01-05 23:04:00.823] [float-tetwild] [info] after winding number
# [2026-01-05 23:04:00.823] [float-tetwild] [info] #v = 6883
# [2026-01-05 23:04:00.823] [float-tetwild] [info] #t = 18067
# [2026-01-05 23:04:00.823] [float-tetwild] [info] winding number 1.04896e+06s
# [2026-01-05 23:04:00.823] [float-tetwild] [info]

# %% [markdown]
# Next we check the *marker* values returned by *fTetWild* and set our own subdomain ids and write the mesh to file:

# %%
subdomains = np.copy(marker)
subdomains[np.isin(marker, [1,2])] = fluid_id
subdomains[np.isin(marker, [3,4])] = porous_id
subdomains[np.isin(marker, [5])] = 3
subdomains[np.isin(marker, [6])] = 4
labels = np.copy(subdomains)
subdomains[np.isin(subdomains, [3,4])] = fluid_id
meshio_mesh = meshio.Mesh(point_array, [("tetra", cell_array)],
                       cell_data={"gmsh:physical": [marker.ravel()],
                                  "labels": [labels.ravel()],
                                  "subdomains": [subdomains.ravel()]})
meshio_mesh.write("mesh/idealized_ftetwild.xdmf")

# %% [markdown]
# Finally, we check the resulting mesh by reading it back in and plotting it:

# %%
pv_mesh = pv.read_meshio("mesh/idealized_ftetwild.xdmf").clean() # changed from pv.read to pv.read_meshio
pv_mesh.clip(normal=(1,0,0),crinkle=True).plot("subdomains" ,show_edges=True, background="white")
# Out:
# /var/folders/86/ypcw7b6x6kx7ctt5dslpqwz40000gn/T/ipykernel_75896/602947742.py:2: PyVistaDeprecationWarning:
# ../../../../var/folders/86/ypcw7b6x6kx7ctt5dslpqwz40000gn/T/ipykernel_75896/602947742.py:2: Argument 'off_screen' must be passed as a keyword argument to function 'plot'.
# From version 0.50, passing this as a positional argument will result in a TypeError.
#   pv_mesh.clip(normal=(1,0,0),crinkle=True).plot("subdomains" ,show_edges=True, background="white")
# /Users/ingvildsd/miniforge3/envs/brainpulse_new/lib/python3.13/site-packages/pyvista/jupyter/notebook.py:56: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %% [markdown]
# ### Generating subdomain restrictions for Multiphenics
#
# To create function spaces restricted to a subdomain of the whole mesh with *MultiPhenics*, we need to create and save so-called *MeshRestrictions* prior to the main simulation run:

# %%
from fenics import *
from multiphenics import *

def generate_subdomain_restriction(mesh, subdomains, subdomain_id):
    D = mesh.topology().dim()
    # Initialize empty restriction
    restriction = MeshRestriction(mesh, None)
    for d in range(D + 1):
        mesh_function_d = MeshFunction("bool", mesh, d)
        mesh_function_d.set_all(False)
        restriction.append(mesh_function_d)
    # Mark restriction mesh functions based on subdomain id
    for c in cells(mesh):
        if subdomains[c] == subdomain_id:
            restriction[D][c] = True
            for d in range(D):
                for e in entities(c, d):
                    restriction[d][e] = True
    # Return
    return restriction

# %%
fenics_mesh = Mesh()
with XDMFFile("mesh/idealized_ftetwild.xdmf") as f:
    f.read(fenics_mesh)
    sm = MeshFunction("size_t", fenics_mesh, 3, 0)
    labels = MeshFunction("size_t", fenics_mesh, 3, 0)
    f.read(sm, "subdomains")
    f.read(labels, "labels")
    sm.rename("subdomains","")

fluid_restr = generate_subdomain_restriction(fenics_mesh, sm, fluid_id)
porous_restr = generate_subdomain_restriction(fenics_mesh, sm, porous_id)
fluid_restr._write("mesh/idealized_fluid.rtc.xdmf")
porous_restr._write("mesh/idealized_porous.rtc.xdmf")

# %% [markdown]
# ## Marking Boundaries and Interfaces
# We mark both the internal interface by looping over all facets in the mesh, checking the subdomain ids of the corresponding cells and identifying the internal interfaces.
# In addition to the tissue-CSF interface, we also mark the surface between the aqueduct and the fourth ventricle, since we would like to compute aqueduct flow rates in the post-processing step.

# %%
bm = MeshFunction("size_t", fenics_mesh, 2, 0)

def mark_internal_interface(mesh, subdomains, bm, interface_id,
                            doms=None):
    # set internal interface
    for f in facets(mesh):
        domains = []
        for c in cells(f):
            domains.append(subdomains[c])
        domains = set(domains)
        if len(domains)==2:
            if doms is None:
                bm[f] = interface_id
            elif set(doms)==domains:
                bm[f] = interface_id

# mark tissue-CSF interface
mark_internal_interface(fenics_mesh, sm, bm, interface_id)
# mark aqueduct-fourth ventricle interface for later flow computation
mark_internal_interface(fenics_mesh, labels, bm, aqueduct_V4_id, doms=[3,4])

# %% [markdown]
# Similarly, we mark the external boundaries by a combination of the facet location and the subdomain id of the corresponding subdomain:

# %%
def mark_external_boundaries(mesh, subdomains, boundaries, 
                             subdomain_ids, new_boundary_id):
    for f in facets(mesh):
        if not f.exterior():
            continue
        c = list(cells(f))[0]
        if subdomains[c] in subdomain_ids:
            boundaries[f] = new_boundary_id
                
z_min = fenics_mesh.coordinates()[:,2].min()
bottom = CompiledSubDomain("on_boundary && near(x[2], v, tol)",
                        v=z_min, tol=0.001)
outer = CompiledSubDomain("on_boundary")
outer.mark(bm, skull_id)
bottom.mark(bm, spinal_canal_id)
mark_external_boundaries(fenics_mesh, sm, bm, 
                         [porous_id], spinal_cord_id)

with XDMFFile("mesh/idealized_boundaries.xdmf") as f:
    f.write(bm)
with XDMFFile("mesh/idealized.xdmf") as f:
    f.write(sm)
