# %% [markdown]
# ### Multidomain Mesh Generation with fTetWild
#
# In this notebook, we demonstrate how to generate a multidomain idealized brain mesh using boolean operations on surface meshes (STLs) with [fTetWild](https://wildmeshing.github.io/ftetwild/).
#
# First, we import the relevant packages and set the ids of the subdomains and boundaries we want to mark:

# %%
import wildmeshing as wm
import pyvista as pv
import numpy as np
import meshio
import json
from pathlib import Path

# domain ids
porous_id = 1
fluid_id = 2

# facet ids
#skull_id = 1
#spinal_canal_id = 2
#interface_id = 3
#spinal_cord_id = 4
#aqueduct_V4_id = 5

interface_id = 1
skull_id = 2
spinal_canal_id = 3
spinal_cord_id = 4
aqueduct_V4_id = 5

# %% [markdown]
# As our geometry consists of multiple spheres and cylinders, we create surface meshes for each of the components with PyVista and plot them to check the setup:

# %%
skull = pv.Sphere(radius = 0.08)
parenchyma = pv.Sphere(radius = 0.07)
ventricle = pv.Sphere(radius = 0.02)
canal = pv.Cylinder(center=(0, 0, -0.105), direction=(0,0,-1),
                        radius=0.025, height=0.08).triangulate()
cord = pv.Cylinder(center=(0, 0, -0.105), direction=(0,0,-1),
                        radius=0.017, height=0.08).triangulate()
aqueduct = pv.Cylinder(center=(0, 0.03, -0.03), direction=(0,1,-1),
                       radius=0.004, height=0.06).triangulate()

# display the geometry using PyVista
pl = pv.Plotter()
pl.add_mesh(parenchyma, opacity=.6, color="blue")
pl.add_mesh(ventricle,  color="red")
pl.add_mesh(aqueduct, opacity=0.7, color="red")
pl.add_mesh(skull, opacity=0.2)
pl.add_mesh(canal, opacity=0.2)
pl.add_mesh(cord, opacity=0.7, color="blue")
pl.background_color = "white"
pl.show()
# Out:
# /Users/ingvildsd/miniforge3/envs/brainpulse_new/lib/python3.13/site-packages/pyvista/jupyter/notebook.py:56: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
# save the surface meshes for later use by fTetWild
stl_directory = Path("stls/")
stl_directory.mkdir(exist_ok=True, parents=True)
parenchyma.save(stl_directory / "parenchyma.stl")
skull.save(stl_directory / "skull.stl")
cord.save(stl_directory / "cord.stl")
canal.save(stl_directory / "canal.stl")
ventricle.save(stl_directory / "ventricle.stl")
aqueduct.save(stl_directory / "aqueduct.stl")

# %% [markdown]
# Now, we have everything in place to define a constructive solid geometry(CSG)-tree, describing the order and type of boolean operations carried out on the surface meshes:
#
# * first, we take the union of brain tissue components: parenchyma and spinal cord
# * then, we subtract the ventricle and aqueduct parts from the tissue
# * finally, we take the union of the outermost sphere and cylinder with the result of the previous steps
#
# Further, we specify maximum distance between the input surfaces and the surface of the generated volumetric mesh with the *epsilon* parameter (specifying the relative envelop size) and relative edge length with *edge_length_r*.
#
# Note that while we use a simple geometry here, we can easily replace the STL files with complex shapes and apply the same procedure to generate image-derived realistic models.

# %%
tetra = wm.Tetrahedralizer(epsilon=0.002, edge_length_r=0.05,
                           coarsen=False)
tetra.load_csg_tree(json.dumps(
    {"operation":"union",
     "right":
          {
          "operation":"difference",
          "left":{"operation":"union", "left": str(stl_directory / "parenchyma.stl"),
                              "right": str(stl_directory / "cord.stl")},
          "right":{"operation":"union", "left": str(stl_directory / "aqueduct.stl"),
                          "right":str(stl_directory / "ventricle.stl")},
          },
     "left":
        {"operation":"union", "left": str(stl_directory / "skull.stl"),
                          "right":str(stl_directory / "canal.stl")},                
    }
))
tetra.tetrahedralize()
point_array, cell_array, marker = tetra.get_tet_mesh()
# Out:
# TBB threads 12
# o-[I/O         ] Loading file stls/skull.stl...
#                  (FP64) nb_v:5040 nb_e:0 nb_f:1680 nb_b:5040 tri:1 dim:3
#                  Attributes on vertices: point[3]
#                  Loading file stls/canal.stl...
#                  (FP64) nb_v:1188 nb_e:0 nb_f:396 nb_b:1188 tri:1 dim:3
#                  Attributes on vertices: point[3]
#                  Loading file stls/parenchyma.stl...
#                  (FP64) nb_v:5040 nb_e:0 nb_f:1680 nb_b:5040 tri:1 dim:3
#                  Attributes on vertices: point[3]
#                  Loading file stls/cord.stl...
#                  (FP64) nb_v:1188 nb_e:0 nb_f:396 nb_b:1188 tri:1 dim:3
#                  Attributes on vertices: point[3]
#                  Loading file stls/aqueduct.stl...
#                  (FP64) nb_v:1188 nb_e:0 nb_f:396 nb_b:1188 tri:1 dim:3
#                  Attributes on vertices: point[3]
#                  Loading file stls/ventricle.stl...
#                  (FP64) nb_v:5040 nb_e:0 nb_f:1680 nb_b:5040 tri:1 dim:3
#                  Attributes on vertices: point[3]
# bbox_diag_length = 0.318427
# ideal_edge_length = 0.0159214
# stage = 2
# eps_input = 0.000636855
# eps = 0.000352556
# eps_simplification = 0.000282045
# eps_coplanar = 3.18427e-07
# dd = 0.00042457
# dd_simplification = 0.000339656
# [2026-01-05 22:32:41.762] [float-tetwild] [info] remove duplicates:
# [2026-01-05 22:32:41.762] [float-tetwild] [info] #v: 18684 -> 3126
# [2026-01-05 22:32:41.762] [float-tetwild] [info] #f: 6228 -> 6228
# collapsing 0.0905544
# swapping 0.0263273
# [2026-01-05 22:32:41.881] [float-tetwild] [info] remove duplicates:
# [2026-01-05 22:32:41.881] [float-tetwild] [info] #v: 1778 -> 1778
# [2026-01-05 22:32:41.881] [float-tetwild] [info] #f: 3528 -> 3528
# [2026-01-05 22:32:41.881] [float-tetwild] [info] #v = 1778
# [2026-01-05 22:32:41.881] [float-tetwild] [info] #f = 3528
# #boundary_e1 = 12
# #boundary_e2 = 0
# [2026-01-05 22:32:41.884] [float-tetwild] [info] preprocessing 0.122838s
# [2026-01-05 22:32:41.884] [float-tetwild] [info]
# [2026-01-05 22:32:41.905] [float-tetwild] [info] #v = 2840
# [2026-01-05 22:32:41.905] [float-tetwild] [info] #t = 15819
# [2026-01-05 22:32:41.905] [float-tetwild] [info] tetrahedralizing 0.020901s
# [2026-01-05 22:32:41.905] [float-tetwild] [info]
# [2026-01-05 22:32:41.905] [float-tetwild] [info] triangle insertion start, #f = 3528, #v = 2840, #t = 15819
# [2026-01-05 22:32:41.908] [float-tetwild] [info] matched #f = 2523, uninserted #f = 1005
# FAIL subdivide_tets
# FAIL subdivide_tets
# FAIL subdivide_tets
# FAIL subdivide_tets
# FAIL subdivide_tets
# FAIL subdivide_tets
# FAIL subdivide_tets
# [2026-01-05 22:32:42.706] [float-tetwild] [info] insert_one_triangle * n done, #v = 44710, #t = 242091
# [2026-01-05 22:32:42.706] [float-tetwild] [info] uninserted #f = 7/1005
# [2026-01-05 22:32:42.706] [float-tetwild] [info] total timing: 0s
# [2026-01-05 22:32:42.788] [float-tetwild] [info] pair_track_surface_fs done
# #boundary_e1 = 31
# #boundary_e2 = 0
# [2026-01-05 22:32:42.790] [float-tetwild] [info] find_boundary_edges done
# [2026-01-05 22:32:42.793] [float-tetwild] [info] time1 = 0.00305088
# [2026-01-05 22:32:42.808] [float-tetwild] [info] uninsert boundary #e = 0/31
# [2026-01-05 22:32:42.808] [float-tetwild] [info] time2 = 1e-06
# [2026-01-05 22:32:42.808] [float-tetwild] [info] time3 = 0.00506283
# [2026-01-05 22:32:42.808] [float-tetwild] [info] time4 = 0.00723425
# [2026-01-05 22:32:42.808] [float-tetwild] [info] time5 = 0.0025225
# [2026-01-05 22:32:42.808] [float-tetwild] [info] time6 = 2.33333e-06
# [2026-01-05 22:32:42.808] [float-tetwild] [info] uninserted #f = 7/1005
# known_surface_fs.size = 0
# known_not_surface_fs.size = 0
# [2026-01-05 22:32:43.083] [float-tetwild] [info] mark_surface_fs done
# [2026-01-05 22:32:43.083] [float-tetwild] [info] #b_edge1 = 31, #b_edges2 = 0
# [2026-01-05 22:32:43.093] [float-tetwild] [info] cutting 1.18858s
# [2026-01-05 22:32:43.093] [float-tetwild] [info]
# initializing...
# edge collapsing...
# fixed 0 tangled element
# success(env) = 34486
# success = 36737(183445)
# success(env) = 1715
# success = 1920(34942)
# success(env) = 326
# success = 376(17551)
# success(env) = 82
# success = 94(10414)
# success(env) = 26
# success = 28(5524)
# success(env) = 6
# success = 6(2432)
# success(env) = 2
# success = 5(280)
# success(env) = 1
# success = 1(96)
# success(env) = 2
# success = 2(78)
# success(env) = 1
# success = 1(99)
# success(env) = 1
# success = 1(118)
# success(env) = 0
# success = 0(85)
# edge collapsing done!
# time = 1.97916s
# #v = 3787
# #t = 21799
# max_energy = 502428
# avg_energy = 2093.99
# [2026-01-05 22:32:45.076] [float-tetwild] [info] triangle insertion start, #f = 3528, #v = 46837, #t = 252198
# [2026-01-05 22:32:45.077] [float-tetwild] [info] matched #f = 3521, uninserted #f = 7
# [2026-01-05 22:32:45.115] [float-tetwild] [info] insert_one_triangle * n done, #v = 47997, #t = 258297
# [2026-01-05 22:32:45.115] [float-tetwild] [info] uninserted #f = 0/7
# [2026-01-05 22:32:45.115] [float-tetwild] [info] total timing: 0s
# [2026-01-05 22:32:45.118] [float-tetwild] [info] pair_track_surface_fs done
# #boundary_e1 = 12
# #boundary_e2 = 0
# [2026-01-05 22:32:45.119] [float-tetwild] [info] find_boundary_edges done
# [2026-01-05 22:32:45.120] [float-tetwild] [info] time1 = 0.00058725
# [2026-01-05 22:32:45.120] [float-tetwild] [info] uninsert boundary #e = 0/0
# [2026-01-05 22:32:45.120] [float-tetwild] [info] time2 = 0
# [2026-01-05 22:32:45.120] [float-tetwild] [info] time3 = 0
# [2026-01-05 22:32:45.120] [float-tetwild] [info] time4 = 0
# [2026-01-05 22:32:45.120] [float-tetwild] [info] time5 = 0
# [2026-01-05 22:32:45.120] [float-tetwild] [info] time6 = 0
# [2026-01-05 22:32:45.120] [float-tetwild] [info] uninserted #f = 0/7
# known_surface_fs.size = 0
# known_not_surface_fs.size = 0
# [2026-01-05 22:32:45.129] [float-tetwild] [info] mark_surface_fs done
# [2026-01-05 22:32:45.130] [float-tetwild] [info] #b_edge1 = 12, #b_edges2 = 0
# initializing...
# //////////////// pass 0 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 8269(8269)
# edge splitting done!
# time = 0.0359772s
# #v = 12993
# #t = 69674
# max_energy = 1.03591e+06
# avg_energy = 794.395
# edge collapsing...
# fixed 0 tangled element
# success(env) = 965
# success = 7325(48630)
# success(env) = 131
# success = 389(21046)
# success(env) = 34
# success = 57(8778)
# success(env) = 7
# success = 12(2438)
# success(env) = 2
# success = 4(727)
# success(env) = 7
# success = 7(415)
# success(env) = 0
# success = 0(415)
# edge collapsing done!
# time = 0.353505s
# #v = 5199
# #t = 27906
# max_energy = 502428
# avg_energy = 1602.22
# edge swapping...
# fixed 0 tangled element
# success3 = 1567
# success4 = 2307
# success5 = 278
# success = 4152(22847)
# edge swapping done!
# time = 0.125026s
# #v = 5199
# #t = 26617
# max_energy = 159532
# avg_energy = 35.5581
# vertex smoothing...
# success = 2697(4033)
# vertex smoothing done!
# time = 0.0293458s
# #v = 5199
# #t = 26617
# max_energy = 159532
# avg_energy = 30.2056
# //////////////// pass 1 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 3496(3496)
# edge splitting done!
# time = 0.024439s
# #v = 8695
# #t = 42605
# max_energy = 159532
# avg_energy = 20.4723
# edge collapsing...
# fixed 0 tangled element
# success(env) = 211
# success = 3406(32399)
# success(env) = 28
# success = 119(14173)
# success(env) = 5
# success = 8(3111)
# success(env) = 1
# success = 1(622)
# success(env) = 0
# success = 0(138)
# edge collapsing done!
# time = 0.20566s
# #v = 5161
# #t = 26483
# max_energy = 159532
# avg_energy = 29.6964
# edge swapping...
# fixed 0 tangled element
# success3 = 135
# success4 = 874
# success5 = 67
# success = 1076(16973)
# edge swapping done!
# time = 0.0996788s
# #v = 5161
# #t = 26415
# max_energy = 159532
# avg_energy = 22.3938
# vertex smoothing...
# success = 2738(4014)
# vertex smoothing done!
# time = 0.0259621s
# #v = 5161
# #t = 26415
# max_energy = 159532
# avg_energy = 22.279
# //////////////// pass 2 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 2911(2911)
# edge splitting done!
# time = 0.0231823s
# #v = 8072
# #t = 39001
# max_energy = 159532
# avg_energy = 16.4538
# edge collapsing...
# fixed 0 tangled element
# success(env) = 37
# success = 2746(30128)
# success(env) = 5
# success = 68(8958)
# success(env) = 0
# success = 3(1005)
# success(env) = 0
# success = 0(51)
# edge collapsing done!
# time = 0.151531s
# #v = 5255
# #t = 26846
# max_energy = 159532
# avg_energy = 21.9694
# edge swapping...
# fixed 0 tangled element
# success3 = 48
# success4 = 491
# success5 = 26
# success = 565(16431)
# edge swapping done!
# time = 0.0826219s
# #v = 5255
# #t = 26824
# max_energy = 159532
# avg_energy = 20.2616
# vertex smoothing...
# success = 2696(4052)
# vertex smoothing done!
# time = 0.024573s
# #v = 5255
# #t = 26824
# max_energy = 159532
# avg_energy = 20.2149
# updating sclaing field ...
# filter_energy = 100
# is_hit_min_edge_length = 0
# enlarge envelope, eps = 0.000391729
# //////////////// pass 3 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 2951(2951)
# edge splitting done!
# time = 0.023505s
# #v = 8206
# #t = 39692
# max_energy = 146188
# avg_energy = 60.1656
# edge collapsing...
# fixed 0 tangled element
# success(env) = 82
# success = 2747(29840)
# success(env) = 6
# success = 76(9786)
# success(env) = 0
# success = 3(706)
# success(env) = 0
# success = 1(42)
# success(env) = 0
# success = 2(3)
# success(env) = 0
# success = 0(6)
# edge collapsing done!
# time = 0.153601s
# #v = 5377
# #t = 27510
# max_energy = 49.7076
# avg_energy = 3.90984
# edge swapping...
# fixed 0 tangled element
# success3 = 39
# success4 = 422
# success5 = 19
# success = 480(17026)
# edge swapping done!
# time = 0.087217s
# #v = 5377
# #t = 27490
# max_energy = 49.7076
# avg_energy = 3.8912
# vertex smoothing...
# success = 2877(4178)
# vertex smoothing done!
# time = 0.025708s
# #v = 5377
# #t = 27490
# max_energy = 49.7076
# avg_energy = 3.84691
# //////////////// pass 4 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 2645(2645)
# edge splitting done!
# time = 0.0232422s
# #v = 8022
# #t = 38662
# max_energy = 49.5802
# avg_energy = 3.95039
# edge collapsing...
# fixed 0 tangled element
# success(env) = 30
# success = 2521(29045)
# success(env) = 1
# success = 48(6901)
# success(env) = 0
# success = 5(426)
# success(env) = 0
# success = 1(43)
# success(env) = 0
# success = 0(38)
# edge collapsing done!
# time = 0.133286s
# #v = 5447
# #t = 27868
# max_energy = 39.8782
# avg_energy = 3.85711
# edge swapping...
# fixed 0 tangled element
# success3 = 19
# success4 = 349
# success5 = 12
# success = 380(17235)
# edge swapping done!
# time = 0.084063s
# #v = 5447
# #t = 27861
# max_energy = 39.8782
# avg_energy = 3.84579
# vertex smoothing...
# success = 2791(4210)
# vertex smoothing done!
# time = 0.023915s
# #v = 5447
# #t = 27861
# max_energy = 37.8007
# avg_energy = 3.8199
# //////////////// pass 5 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 2517(2517)
# edge splitting done!
# time = 0.0231972s
# #v = 7964
# #t = 38339
# max_energy = 37.8007
# avg_energy = 3.92293
# edge collapsing...
# fixed 0 tangled element
# success(env) = 20
# success = 2380(28769)
# success(env) = 0
# success = 59(5916)
# success(env) = 0
# success = 0(391)
# edge collapsing done!
# time = 0.12626s
# #v = 5525
# #t = 28270
# max_energy = 37.8007
# avg_energy = 3.8379
# edge swapping...
# fixed 0 tangled element
# success3 = 13
# success4 = 287
# success5 = 17
# success = 317(17564)
# edge swapping done!
# time = 0.0849095s
# #v = 5525
# #t = 28274
# max_energy = 37.8007
# avg_energy = 3.83187
# vertex smoothing...
# success = 2772(4271)
# vertex smoothing done!
# time = 0.0240932s
# #v = 5525
# #t = 28274
# max_energy = 37.6012
# avg_energy = 3.8113
# updating sclaing field ...
# filter_energy = 8
# is_hit_min_edge_length = 0
# //////////////// pass 6 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 3578(3578)
# edge splitting done!
# time = 0.0262372s
# #v = 9103
# #t = 44360
# max_energy = 38.906
# avg_energy = 4.01847
# edge collapsing...
# fixed 0 tangled element
# success(env) = 154
# success = 3011(29816)
# success(env) = 3
# success = 104(10287)
# success(env) = 0
# success = 8(1099)
# success(env) = 0
# success = 6(149)
# success(env) = 0
# success = 6(121)
# success(env) = 0
# success = 2(47)
# success(env) = 0
# success = 0(33)
# edge collapsing done!
# time = 0.170121s
# #v = 5966
# #t = 30802
# max_energy = 32.4214
# avg_energy = 3.82168
# edge swapping...
# fixed 0 tangled element
# success3 = 55
# success4 = 487
# success5 = 36
# success = 578(20193)
# edge swapping done!
# time = 0.117904s
# #v = 5966
# #t = 30783
# max_energy = 32.4214
# avg_energy = 3.79807
# vertex smoothing...
# success = 3236(4709)
# vertex smoothing done!
# time = 0.030205s
# #v = 5966
# #t = 30783
# max_energy = 27.294
# avg_energy = 3.7475
# //////////////// pass 7 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 2613(2613)
# edge splitting done!
# time = 0.0255361s
# #v = 8579
# #t = 41686
# max_energy = 27.294
# avg_energy = 3.87095
# edge collapsing...
# fixed 0 tangled element
# success(env) = 58
# success = 2498(27707)
# success(env) = 5
# success = 67(7809)
# success(env) = 0
# success = 5(833)
# success(env) = 0
# success = 1(89)
# success(env) = 0
# success = 0(7)
# edge collapsing done!
# time = 0.13882s
# #v = 6008
# #t = 31032
# max_energy = 27.294
# avg_energy = 3.75994
# edge swapping...
# fixed 0 tangled element
# success3 = 21
# success4 = 354
# success5 = 12
# success = 387(20016)
# edge swapping done!
# time = 0.099774s
# #v = 6008
# #t = 31023
# max_energy = 27.294
# avg_energy = 3.75005
# vertex smoothing...
# success = 3200(4704)
# vertex smoothing done!
# time = 0.0253493s
# #v = 6008
# #t = 31023
# max_energy = 27.294
# avg_energy = 3.72465
# updating sclaing field ...
# filter_energy = 8
# is_hit_min_edge_length = 0
# //////////////// pass 8 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 4010(4010)
# edge splitting done!
# time = 0.029163s
# #v = 10018
# #t = 49507
# max_energy = 27.294
# avg_energy = 4.00861
# edge collapsing...
# fixed 0 tangled element
# success(env) = 282
# success = 3147(35024)
# success(env) = 26
# success = 115(11639)
# success(env) = 5
# success = 15(1380)
# success(env) = 2
# success = 4(338)
# success(env) = 1
# success = 2(101)
# success(env) = 0
# success = 0(59)
# edge collapsing done!
# time = 0.184211s
# #v = 6735
# #t = 35126
# max_energy = 18.2295
# avg_energy = 3.76173
# edge swapping...
# fixed 0 tangled element
# success3 = 66
# success4 = 595
# success5 = 25
# success = 686(23623)
# edge swapping done!
# time = 0.141112s
# #v = 6735
# #t = 35085
# max_energy = 18.2295
# avg_energy = 3.73464
# vertex smoothing...
# success = 3807(5390)
# vertex smoothing done!
# time = 0.0303439s
# #v = 6735
# #t = 35085
# max_energy = 18.5339
# avg_energy = 3.67751
# //////////////// pass 9 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 2514(2514)
# edge splitting done!
# time = 0.0280436s
# #v = 9249
# #t = 45401
# max_energy = 14.8796
# avg_energy = 3.80182
# edge collapsing...
# fixed 0 tangled element
# success(env) = 162
# success = 2436(32205)
# success(env) = 7
# success = 72(9094)
# success(env) = 2
# success = 8(862)
# success(env) = 0
# success = 1(121)
# success(env) = 0
# success = 0(11)
# edge collapsing done!
# time = 0.150354s
# #v = 6732
# #t = 35096
# max_energy = 10.6915
# avg_energy = 3.68406
# edge swapping...
# fixed 0 tangled element
# success3 = 20
# success4 = 383
# success5 = 17
# success = 420(23196)
# edge swapping done!
# time = 0.105708s
# #v = 6732
# #t = 35093
# max_energy = 10.6915
# avg_energy = 3.67537
# vertex smoothing...
# success = 3751(5372)
# vertex smoothing done!
# time = 0.0277598s
# #v = 6732
# #t = 35093
# max_energy = 10.1451
# avg_energy = 3.6482
# //////////////// pass 10 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 2341(2341)
# edge splitting done!
# time = 0.0270518s
# #v = 9073
# #t = 44506
# max_energy = 10.1451
# avg_energy = 3.76505
# edge collapsing...
# fixed 0 tangled element
# success(env) = 116
# success = 2258(31393)
# success(env) = 7
# success = 63(7947)
# success(env) = 0
# success = 4(580)
# success(env) = 0
# success = 0(24)
# edge collapsing done!
# time = 0.136441s
# #v = 6748
# #t = 35172
# max_energy = 9.65981
# avg_energy = 3.65954
# edge swapping...
# fixed 0 tangled element
# success3 = 17
# success4 = 274
# success5 = 8
# success = 299(23130)
# edge swapping done!
# time = 0.101841s
# #v = 6748
# #t = 35163
# max_energy = 9.65981
# avg_energy = 3.6527
# vertex smoothing...
# success = 3707(5396)
# vertex smoothing done!
# time = 0.0266947s
# #v = 6748
# #t = 35163
# max_energy = 9.62399
# avg_energy = 3.63549
# //////////////// postprocessing ////////////////
# edge collapsing...
# fixed 0 tangled element
# success(env) = 17
# success = 86(38258)
# success(env) = 1
# success = 9(4215)
# success(env) = 0
# success = 1(441)
# success(env) = 0
# success = 0(132)
# edge collapsing done!
# time = 0.118905s
# #v = 6652
# #t = 34694
# max_energy = 9.45536
# avg_energy = 3.63532
# [2026-01-05 22:32:48.914] [float-tetwild] [info] mesh optimization 5.81908s
# [2026-01-05 22:32:48.914] [float-tetwild] [info]
# [2026-01-05 22:32:48.927] [float-tetwild] [info] correct_tracked_surface_orientation done
# [2026-01-05 22:32:48.984] [float-tetwild] [info] after winding number
# [2026-01-05 22:32:48.984] [float-tetwild] [info] #v = 6652
# [2026-01-05 22:32:48.984] [float-tetwild] [info] #t = 16704
# [2026-01-05 22:32:48.984] [float-tetwild] [info] winding number 1.04709e+06s
# [2026-01-05 22:32:48.984] [float-tetwild] [info]

# %% [markdown]
# Next we check the *marker* values returned by *fTetWild* and set our own subdomain ids and write the mesh to file:

# %%
subdomains = np.copy(marker)
subdomains[np.isin(marker, [1,2])] = fluid_id
subdomains[np.isin(marker, [3,4])] = porous_id
subdomains[np.isin(marker, [5])] = 3
subdomains[np.isin(marker, [6])] = 4
labels = np.copy(subdomains)
subdomains[np.isin(subdomains, [3,4])] = fluid_id
meshio_mesh = meshio.Mesh(point_array, [("tetra", cell_array)],
                       cell_data={"gmsh:physical": [marker.ravel()],
                                  "labels": [labels.ravel()],
                                  "subdomains": [subdomains.ravel()]})
meshio_mesh.write("mesh/idealized.xdmf")

# %% [markdown]
# Finally, we check the resulting mesh by reading it back in and plotting it:

# %%
pv_mesh = pv.read_meshio("mesh/idealized.xdmf").clean() # changed from pv.read to pv.read_meshio
pv_mesh.clip(normal=(1,0,0),crinkle=True).plot("subdomains" ,show_edges=True, background="white")
# Out:
# /var/folders/86/ypcw7b6x6kx7ctt5dslpqwz40000gn/T/ipykernel_55226/2742215626.py:2: PyVistaDeprecationWarning:
# ../../../../var/folders/86/ypcw7b6x6kx7ctt5dslpqwz40000gn/T/ipykernel_55226/2742215626.py:2: Argument 'off_screen' must be passed as a keyword argument to function 'plot'.
# From version 0.50, passing this as a positional argument will result in a TypeError.
#   pv_mesh.clip(normal=(1,0,0),crinkle=True).plot("subdomains" ,show_edges=True, background="white")
# /Users/ingvildsd/miniforge3/envs/brainpulse_new/lib/python3.13/site-packages/pyvista/jupyter/notebook.py:56: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %% [markdown]
# ### Generating subdomain restrictions for Multiphenics
#
# To create function spaces restricted to a subdomain of the whole mesh with *MultiPhenics*, we need to create and save so-called *MeshRestrictions* prior to the main simulation run:

# %%
from fenics import *
from multiphenics import *

def generate_subdomain_restriction(mesh, subdomains, subdomain_id):
    D = mesh.topology().dim()
    # Initialize empty restriction
    restriction = MeshRestriction(mesh, None)
    for d in range(D + 1):
        mesh_function_d = MeshFunction("bool", mesh, d)
        mesh_function_d.set_all(False)
        restriction.append(mesh_function_d)
    # Mark restriction mesh functions based on subdomain id
    for c in cells(mesh):
        if subdomains[c] == subdomain_id:
            restriction[D][c] = True
            for d in range(D):
                for e in entities(c, d):
                    restriction[d][e] = True
    # Return
    return restriction
# Out:
# /Users/ingvildsd/miniforge3/envs/brainpulse_new/lib/python3.13/site-packages/ufl/__init__.py:250: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
fenics_mesh = Mesh()
with XDMFFile("mesh/idealized.xdmf") as f:
    f.read(fenics_mesh)
    sm = MeshFunction("size_t", fenics_mesh, 3, 0)
    labels = MeshFunction("size_t", fenics_mesh, 3, 0)
    f.read(sm, "subdomains")
    f.read(labels, "labels")
    sm.rename("subdomains","")

fluid_restr = generate_subdomain_restriction(fenics_mesh, sm, fluid_id)
porous_restr = generate_subdomain_restriction(fenics_mesh, sm, porous_id)
fluid_restr._write("mesh/idealized_fluid.rtc.xdmf")
porous_restr._write("mesh/idealized_porous.rtc.xdmf")

# %% [markdown]
# ## Marking Boundaries and Interfaces
# We mark both the internal interface by looping over all facets in the mesh, checking the subdomain ids of the corresponding cells and identifying the internal interfaces.
# In addition to the tissue-CSF interface, we also mark the surface between the aqueduct and the fourth ventricle, since we would like to compute aqueduct flow rates in the post-processing step.

# %%
bm = MeshFunction("size_t", fenics_mesh, 2, 0)

def mark_internal_interface(mesh, subdomains, bm, interface_id,
                            doms=None):
    # set internal interface
    for f in facets(mesh):
        domains = []
        for c in cells(f):
            domains.append(subdomains[c])
        domains = set(domains)
        if len(domains)==2:
            if doms is None:
                bm[f] = interface_id
            elif set(doms)==domains:
                bm[f] = interface_id

# mark tissue-CSF interface
mark_internal_interface(fenics_mesh, sm, bm, interface_id)
# mark aqueduct-fourth ventricle interface for later flow computation
mark_internal_interface(fenics_mesh, labels, bm, aqueduct_V4_id, doms=[3,4])

# %% [markdown]
# Similarly, we mark the external boundaries by a combination of the facet location and the subdomain id of the corresponding subdomain:

# %%
def mark_external_boundaries(mesh, subdomains, boundaries, 
                             subdomain_ids, new_boundary_id):
    for f in facets(mesh):
        if not f.exterior():
            continue
        c = list(cells(f))[0]
        if subdomains[c] in subdomain_ids:
            boundaries[f] = new_boundary_id
                
z_min = fenics_mesh.coordinates()[:,2].min()
bottom = CompiledSubDomain("on_boundary && near(x[2], v, tol)",
                        v=z_min, tol=0.001)
outer = CompiledSubDomain("on_boundary")
outer.mark(bm, skull_id)
bottom.mark(bm, spinal_canal_id)
mark_external_boundaries(fenics_mesh, sm, bm, 
                         [porous_id], spinal_cord_id)

with XDMFFile("mesh/idealized_boundaries.xdmf") as f:
    f.write(bm)
with XDMFFile("mesh/idealized.xdmf") as f:
    f.write(sm)
