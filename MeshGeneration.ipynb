# %% [markdown]
# ### Multidomain Mesh Generation with fTetWild
#
# In this notebook, we demonstrate how to generate a multidomain idealized brain mesh using boolean operations on surface meshes (STLs) with [fTetWild](https://wildmeshing.github.io/ftetwild/).
#
# First, we import the relevant packages and set the ids of the subdomains and boundaries we want to mark:

# %%
import wildmeshing as wm
import pyvista as pv
import numpy as np
import meshio
import json
from pathlib import Path

# domain ids
porous_id = 1
fluid_id = 2

# facet ids
#skull_id = 1
#spinal_canal_id = 2
#interface_id = 3
#spinal_cord_id = 4
#aqueduct_V4_id = 5

interface_id = 1
skull_id = 2
spinal_canal_id = 3
spinal_cord_id = 4
aqueduct_V4_id = 5

# %% [markdown]
# As our geometry consists of multiple spheres and cylinders, we create surface meshes for each of the components with PyVista and plot them to check the setup:

# %%
skull = pv.Sphere(radius = 0.08)
parenchyma = pv.Sphere(radius = 0.07)
ventricle = pv.Sphere(radius = 0.02)
canal = pv.Cylinder(center=(0, 0, -0.105), direction=(0,0,-1),
                        radius=0.025, height=0.08).triangulate()
cord = pv.Cylinder(center=(0, 0, -0.105), direction=(0,0,-1),
                        radius=0.017, height=0.08).triangulate()
aqueduct = pv.Cylinder(center=(0, 0.03, -0.03), direction=(0,1,-1),
                       radius=0.004, height=0.06).triangulate()

# display the geometry using PyVista
pl = pv.Plotter()
pl.add_mesh(parenchyma, opacity=.6, color="blue")
pl.add_mesh(ventricle,  color="red")
pl.add_mesh(aqueduct, opacity=0.7, color="red")
pl.add_mesh(skull, opacity=0.2)
pl.add_mesh(canal, opacity=0.2)
pl.add_mesh(cord, opacity=0.7, color="blue")
pl.background_color = "white"
pl.show()
# Out:
# /Users/ingvildsd/miniforge3/envs/brainpulse_new/lib/python3.13/site-packages/pyvista/jupyter/notebook.py:56: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
# save the surface meshes for later use by fTetWild
stl_directory = Path("mesh/stls/")
stl_directory.mkdir(exist_ok=True, parents=True)
parenchyma.save(stl_directory / "parenchyma.stl")
skull.save(stl_directory / "skull.stl")
cord.save(stl_directory / "cord.stl")
canal.save(stl_directory / "canal.stl")
ventricle.save(stl_directory / "ventricle.stl")
aqueduct.save(stl_directory / "aqueduct.stl")

# %% [markdown]
# Now, we have everything in place to define a constructive solid geometry(CSG)-tree, describing the order and type of boolean operations carried out on the surface meshes:
#
# * first, we take the union of brain tissue components: parenchyma and spinal cord
# * then, we subtract the ventricle and aqueduct parts from the tissue
# * finally, we take the union of the outermost sphere and cylinder with the result of the previous steps
#
# Further, we specify maximum distance between the input surfaces and the surface of the generated volumetric mesh with the *epsilon* parameter (specifying the relative envelop size) and relative edge length with *edge_length_r*.
#
# Note that while we use a simple geometry here, we can easily replace the STL files with complex shapes and apply the same procedure to generate image-derived realistic models.

# %%
tetra = wm.Tetrahedralizer(epsilon=0.002, edge_length_r=0.05,
                           coarsen=False)
tetra.load_csg_tree(json.dumps(
    {"operation":"union",
     "right":
          {
          "operation":"difference",
          "left":{"operation":"union", "left": str(stl_directory / "parenchyma.stl"),
                              "right": str(stl_directory / "cord.stl")},
          "right":{"operation":"union", "left": str(stl_directory / "aqueduct.stl"),
                          "right":str(stl_directory / "ventricle.stl")},
          },
     "left":
        {"operation":"union", "left": str(stl_directory / "skull.stl"),
                          "right":str(stl_directory / "canal.stl")},                
    }
))
tetra.tetrahedralize()
point_array, cell_array, marker = tetra.get_tet_mesh()
# Out:
# TBB threads 12
# o-[I/O         ] Loading file mesh/stls/skull.stl...
#                  (FP64) nb_v:5040 nb_e:0 nb_f:1680 nb_b:5040 tri:1 dim:3
#                  Attributes on vertices: point[3]
#                  Loading file mesh/stls/canal.stl...
#                  (FP64) nb_v:1188 nb_e:0 nb_f:396 nb_b:1188 tri:1 dim:3
#                  Attributes on vertices: point[3]
#                  Loading file mesh/stls/parenchyma.stl...
#                  (FP64) nb_v:5040 nb_e:0 nb_f:1680 nb_b:5040 tri:1 dim:3
#                  Attributes on vertices: point[3]
#                  Loading file mesh/stls/cord.stl...
#                  (FP64) nb_v:1188 nb_e:0 nb_f:396 nb_b:1188 tri:1 dim:3
#                  Attributes on vertices: point[3]
#                  Loading file mesh/stls/aqueduct.stl...
#                  (FP64) nb_v:1188 nb_e:0 nb_f:396 nb_b:1188 tri:1 dim:3
#                  Attributes on vertices: point[3]
#                  Loading file mesh/stls/ventricle.stl...
#                  (FP64) nb_v:5040 nb_e:0 nb_f:1680 nb_b:5040 tri:1 dim:3
#                  Attributes on vertices: point[3]
# bbox_diag_length = 0.318427
# ideal_edge_length = 0.0159214
# stage = 2
# eps_input = 0.000636855
# eps = 0.000352556
# eps_simplification = 0.000282045
# eps_coplanar = 3.18427e-07
# dd = 0.00042457
# dd_simplification = 0.000339656
# [2026-01-05 22:26:49.684] [float-tetwild] [info] remove duplicates:
# [2026-01-05 22:26:49.684] [float-tetwild] [info] #v: 18684 -> 3126
# [2026-01-05 22:26:49.684] [float-tetwild] [info] #f: 6228 -> 6228
# collapsing 0.0905956
# swapping 0.0261244
# [2026-01-05 22:26:49.802] [float-tetwild] [info] remove duplicates:
# [2026-01-05 22:26:49.802] [float-tetwild] [info] #v: 1778 -> 1778
# [2026-01-05 22:26:49.802] [float-tetwild] [info] #f: 3528 -> 3528
# [2026-01-05 22:26:49.802] [float-tetwild] [info] #v = 1778
# [2026-01-05 22:26:49.802] [float-tetwild] [info] #f = 3528
# #boundary_e1 = 12
# #boundary_e2 = 0
# [2026-01-05 22:26:49.805] [float-tetwild] [info] preprocessing 0.122715s
# [2026-01-05 22:26:49.805] [float-tetwild] [info]
# [2026-01-05 22:26:49.826] [float-tetwild] [info] #v = 2840
# [2026-01-05 22:26:49.826] [float-tetwild] [info] #t = 15819
# [2026-01-05 22:26:49.826] [float-tetwild] [info] tetrahedralizing 0.0204095s
# [2026-01-05 22:26:49.826] [float-tetwild] [info]
# [2026-01-05 22:26:49.826] [float-tetwild] [info] triangle insertion start, #f = 3528, #v = 2840, #t = 15819
# [2026-01-05 22:26:49.829] [float-tetwild] [info] matched #f = 2523, uninserted #f = 1005
# FAIL subdivide_tets
# FAIL subdivide_tets
# FAIL subdivide_tets
# FAIL subdivide_tets
# [2026-01-05 22:26:50.587] [float-tetwild] [info] insert_one_triangle * n done, #v = 41497, #t = 224853
# [2026-01-05 22:26:50.588] [float-tetwild] [info] uninserted #f = 4/1005
# [2026-01-05 22:26:50.588] [float-tetwild] [info] total timing: 0s
# [2026-01-05 22:26:50.662] [float-tetwild] [info] pair_track_surface_fs done
# #boundary_e1 = 24
# #boundary_e2 = 0
# [2026-01-05 22:26:50.664] [float-tetwild] [info] find_boundary_edges done
# [2026-01-05 22:26:50.667] [float-tetwild] [info] time1 = 0.00283083
# [2026-01-05 22:26:50.678] [float-tetwild] [info] uninsert boundary #e = 0/24
# [2026-01-05 22:26:50.678] [float-tetwild] [info] time2 = 8.33333e-07
# [2026-01-05 22:26:50.678] [float-tetwild] [info] time3 = 0.003635
# [2026-01-05 22:26:50.678] [float-tetwild] [info] time4 = 0.00606983
# [2026-01-05 22:26:50.678] [float-tetwild] [info] time5 = 0.00171096
# [2026-01-05 22:26:50.678] [float-tetwild] [info] time6 = 2.20833e-06
# [2026-01-05 22:26:50.679] [float-tetwild] [info] uninserted #f = 4/1005
# known_surface_fs.size = 0
# known_not_surface_fs.size = 0
# [2026-01-05 22:26:50.942] [float-tetwild] [info] mark_surface_fs done
# [2026-01-05 22:26:50.943] [float-tetwild] [info] #b_edge1 = 24, #b_edges2 = 0
# [2026-01-05 22:26:50.953] [float-tetwild] [info] cutting 1.1272s
# [2026-01-05 22:26:50.953] [float-tetwild] [info]
# initializing...
# edge collapsing...
# fixed 0 tangled element
# success(env) = 31158
# success = 33236(173359)
# success(env) = 1720
# success = 1890(35078)
# success(env) = 361
# success = 413(17632)
# success(env) = 94
# success = 108(11023)
# success(env) = 31
# success = 37(5218)
# success(env) = 11
# success = 13(2062)
# success(env) = 7
# success = 9(1331)
# success(env) = 2
# success = 2(583)
# success(env) = 3
# success = 3(147)
# success(env) = 3
# success = 3(96)
# success(env) = 0
# success = 0(149)
# edge collapsing done!
# time = 1.86341s
# #v = 3716
# #t = 21294
# max_energy = 1.01236e+07
# avg_energy = 2584.38
# [2026-01-05 22:26:52.819] [float-tetwild] [info] triangle insertion start, #f = 3528, #v = 43167, #t = 232769
# [2026-01-05 22:26:52.820] [float-tetwild] [info] matched #f = 3524, uninserted #f = 4
# [2026-01-05 22:26:52.838] [float-tetwild] [info] insert_one_triangle * n done, #v = 43609, #t = 235139
# [2026-01-05 22:26:52.838] [float-tetwild] [info] uninserted #f = 0/4
# [2026-01-05 22:26:52.838] [float-tetwild] [info] total timing: 0s
# [2026-01-05 22:26:52.839] [float-tetwild] [info] pair_track_surface_fs done
# #boundary_e1 = 12
# #boundary_e2 = 0
# [2026-01-05 22:26:52.841] [float-tetwild] [info] find_boundary_edges done
# [2026-01-05 22:26:52.841] [float-tetwild] [info] time1 = 0.000507792
# [2026-01-05 22:26:52.841] [float-tetwild] [info] uninsert boundary #e = 0/0
# [2026-01-05 22:26:52.841] [float-tetwild] [info] time2 = 0
# [2026-01-05 22:26:52.841] [float-tetwild] [info] time3 = 0
# [2026-01-05 22:26:52.841] [float-tetwild] [info] time4 = 0
# [2026-01-05 22:26:52.841] [float-tetwild] [info] time5 = 0
# [2026-01-05 22:26:52.841] [float-tetwild] [info] time6 = 0
# [2026-01-05 22:26:52.841] [float-tetwild] [info] uninserted #f = 0/4
# known_surface_fs.size = 0
# known_not_surface_fs.size = 0
# [2026-01-05 22:26:52.847] [float-tetwild] [info] mark_surface_fs done
# [2026-01-05 22:26:52.847] [float-tetwild] [info] #b_edge1 = 12, #b_edges2 = 0
# initializing...
# //////////////// pass 0 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 8142(8142)
# edge splitting done!
# time = 0.0325943s
# #v = 12221
# #t = 65457
# max_energy = 1.30568e+06
# avg_energy = 738.824
# edge collapsing...
# fixed 0 tangled element
# success(env) = 489
# success = 6644(44693)
# success(env) = 103
# success = 348(19933)
# success(env) = 27
# success = 43(8481)
# success(env) = 2
# success = 5(2188)
# success(env) = 6
# success = 10(388)
# success(env) = 2
# success = 3(256)
# success(env) = 0
# success = 0(346)
# edge collapsing done!
# time = 0.321638s
# #v = 5168
# #t = 27671
# max_energy = 502428
# avg_energy = 1605.28
# edge swapping...
# fixed 0 tangled element
# success3 = 1518
# success4 = 2351
# success5 = 288
# success = 4157(22717)
# edge swapping done!
# time = 0.122905s
# #v = 5168
# #t = 26441
# max_energy = 159532
# avg_energy = 38.9345
# vertex smoothing...
# success = 2695(3994)
# vertex smoothing done!
# time = 0.029441s
# #v = 5168
# #t = 26441
# max_energy = 159532
# avg_energy = 32.8871
# //////////////// pass 1 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 3498(3498)
# edge splitting done!
# time = 0.0242911s
# #v = 8666
# #t = 42416
# max_energy = 159532
# avg_energy = 22.0977
# edge collapsing...
# fixed 0 tangled element
# success(env) = 203
# success = 3413(31936)
# success(env) = 13
# success = 96(13509)
# success(env) = 0
# success = 4(1933)
# success(env) = 0
# success = 0(41)
# edge collapsing done!
# time = 0.200011s
# #v = 5153
# #t = 26468
# max_energy = 159532
# avg_energy = 32.216
# edge swapping...
# fixed 0 tangled element
# success3 = 132
# success4 = 871
# success5 = 72
# success = 1075(16863)
# edge swapping done!
# time = 0.0937933s
# #v = 5153
# #t = 26408
# max_energy = 138505
# avg_energy = 22.9697
# vertex smoothing...
# success = 2732(4010)
# vertex smoothing done!
# time = 0.0255194s
# #v = 5153
# #t = 26408
# max_energy = 138505
# avg_energy = 22.849
# //////////////// pass 2 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 2919(2919)
# edge splitting done!
# time = 0.0227071s
# #v = 8072
# #t = 39059
# max_energy = 138505
# avg_energy = 16.817
# edge collapsing...
# fixed 0 tangled element
# success(env) = 31
# success = 2711(30390)
# success(env) = 7
# success = 84(8838)
# success(env) = 3
# success = 7(1285)
# success(env) = 0
# success = 3(398)
# success(env) = 0
# success = 0(3)
# edge collapsing done!
# time = 0.153881s
# #v = 5267
# #t = 26868
# max_energy = 138505
# avg_energy = 22.4961
# edge swapping...
# fixed 0 tangled element
# success3 = 41
# success4 = 491
# success5 = 17
# success = 549(16338)
# edge swapping done!
# time = 0.0838573s
# #v = 5267
# #t = 26844
# max_energy = 138505
# avg_energy = 20.8033
# vertex smoothing...
# success = 2662(4048)
# vertex smoothing done!
# time = 0.024389s
# #v = 5267
# #t = 26844
# max_energy = 138505
# avg_energy = 20.7588
# updating sclaing field ...
# filter_energy = 100
# is_hit_min_edge_length = 0
# enlarge envelope, eps = 0.000391729
# //////////////// pass 3 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 2981(2981)
# edge splitting done!
# time = 0.0231326s
# #v = 8248
# #t = 39861
# max_energy = 123068
# avg_energy = 57.6455
# edge collapsing...
# fixed 0 tangled element
# success(env) = 91
# success = 2762(29429)
# success(env) = 5
# success = 64(9830)
# success(env) = 1
# success = 5(886)
# success(env) = 0
# success = 0(39)
# edge collapsing done!
# time = 0.150772s
# #v = 5417
# #t = 27662
# max_energy = 41.3156
# avg_energy = 3.89285
# edge swapping...
# fixed 0 tangled element
# success3 = 21
# success4 = 391
# success5 = 17
# success = 429(16954)
# edge swapping done!
# time = 0.0907484s
# #v = 5417
# #t = 27658
# max_energy = 41.3156
# avg_energy = 3.88198
# vertex smoothing...
# success = 2857(4184)
# vertex smoothing done!
# time = 0.025639s
# #v = 5417
# #t = 27658
# max_energy = 37.1337
# avg_energy = 3.843
# //////////////// pass 4 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 2628(2628)
# edge splitting done!
# time = 0.0231887s
# #v = 8045
# #t = 38843
# max_energy = 37.1337
# avg_energy = 3.94802
# edge collapsing...
# fixed 0 tangled element
# success(env) = 31
# success = 2554(28471)
# success(env) = 0
# success = 41(6628)
# success(env) = 1
# success = 1(346)
# success(env) = 0
# success = 0(22)
# edge collapsing done!
# time = 0.133847s
# #v = 5449
# #t = 27832
# max_energy = 37.1337
# avg_energy = 3.85199
# edge swapping...
# fixed 0 tangled element
# success3 = 21
# success4 = 291
# success5 = 9
# success = 321(17044)
# edge swapping done!
# time = 0.0821994s
# #v = 5449
# #t = 27820
# max_energy = 37.1337
# avg_energy = 3.84357
# vertex smoothing...
# success = 2750(4184)
# vertex smoothing done!
# time = 0.0243404s
# #v = 5449
# #t = 27820
# max_energy = 37.1337
# avg_energy = 3.82163
# updating sclaing field ...
# filter_energy = 8
# is_hit_min_edge_length = 0
# //////////////// pass 5 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 4120(4120)
# edge splitting done!
# time = 0.0270954s
# #v = 9569
# #t = 46950
# max_energy = 36.2515
# avg_energy = 4.07946
# edge collapsing...
# fixed 0 tangled element
# success(env) = 172
# success = 3355(31518)
# success(env) = 9
# success = 122(11330)
# success(env) = 1
# success = 16(1755)
# success(env) = 0
# success = 2(311)
# success(env) = 0
# success = 0(34)
# edge collapsing done!
# time = 0.182689s
# #v = 6074
# #t = 31411
# max_energy = 27.0503
# avg_energy = 3.83561
# edge swapping...
# fixed 0 tangled element
# success3 = 70
# success4 = 589
# success5 = 35
# success = 694(20605)
# edge swapping done!
# time = 0.119742s
# #v = 6074
# #t = 31376
# max_energy = 27.0503
# avg_energy = 3.80521
# vertex smoothing...
# success = 3369(4785)
# vertex smoothing done!
# time = 0.0265349s
# #v = 6074
# #t = 31376
# max_energy = 27.0503
# avg_energy = 3.74472
# //////////////// pass 6 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 2828(2828)
# edge splitting done!
# time = 0.0257176s
# #v = 8902
# #t = 43490
# max_energy = 27.0503
# avg_energy = 3.8837
# edge collapsing...
# fixed 0 tangled element
# success(env) = 89
# success = 2709(28751)
# success(env) = 7
# success = 71(9204)
# success(env) = 0
# success = 5(633)
# success(env) = 0
# success = 1(96)
# success(env) = 0
# success = 0(17)
# edge collapsing done!
# time = 0.146668s
# #v = 6116
# #t = 31631
# max_energy = 27.0503
# avg_energy = 3.75619
# edge swapping...
# fixed 0 tangled element
# success3 = 40
# success4 = 397
# success5 = 12
# success = 449(20454)
# edge swapping done!
# time = 0.0952572s
# #v = 6116
# #t = 31603
# max_energy = 27.0503
# avg_energy = 3.74273
# vertex smoothing...
# success = 3321(4801)
# vertex smoothing done!
# time = 0.0253895s
# #v = 6116
# #t = 31603
# max_energy = 27.0503
# avg_energy = 3.70978
# updating sclaing field ...
# filter_energy = 8
# is_hit_min_edge_length = 0
# //////////////// pass 7 ////////////////
# edge splitting...
# fixed 0 tangled element
# success = 4087(4087)
# edge splitting done!
# time = 0.0291441s
# #v = 10203
# #t = 50626
# max_energy = 25.9061
# avg_energy = 3.99498
# edge collapsing...
# fixed 0 tangled element
# success(env) = 290
# success = 3258(37627)
# success(env) = 29
# success = 152(11475)
# success(env) = 2
# success = 13(1937)
# success(env) = 0
# success = 1(219)
# success(env) = 0
# success = 0(13)
# edge collapsing done!
# time = 0.187632s
# #v = 6779
# #t = 35428
# max_energy = 20.7363
# avg_energy = 3.75331
# edge swapping...
# fixed 0 tangled element
# success3 = 70
# success4 = 633
# success5 = 36
# success = 739(23850)
# edge swapping done!
# time = 0.134881s
# #v = 6779
# #t = 35394
# max_energy = 20.7363
# avg_energy = 3.73003
# vertex smoothing...
# success = 3868(5452)
# vertex smoothing done!
# time = 0.0312694s
# #v = 6779
# #t = 35394
# max_energy = 9.2247
# avg_energy = 3.67109
# //////////////// postprocessing ////////////////
# edge collapsing...
# fixed 0 tangled element
# success(env) = 32
# success = 161(39359)
# success(env) = 4
# success = 12(8571)
# success(env) = 0
# success = 1(1150)
# success(env) = 0
# success = 0(175)
# edge collapsing done!
# time = 0.12689s
# #v = 6605
# #t = 34497
# max_energy = 9.2247
# avg_energy = 3.66536
# [2026-01-05 22:26:55.728] [float-tetwild] [info] mesh optimization 4.77406s
# [2026-01-05 22:26:55.728] [float-tetwild] [info]
# [2026-01-05 22:26:55.741] [float-tetwild] [info] correct_tracked_surface_orientation done
# [2026-01-05 22:26:55.798] [float-tetwild] [info] after winding number
# [2026-01-05 22:26:55.798] [float-tetwild] [info] #v = 6605
# [2026-01-05 22:26:55.798] [float-tetwild] [info] #t = 17223
# [2026-01-05 22:26:55.798] [float-tetwild] [info] winding number 1.04673e+06s
# [2026-01-05 22:26:55.798] [float-tetwild] [info]

# %% [markdown]
# Next we check the *marker* values returned by *fTetWild* and set our own subdomain ids and write the mesh to file:

# %%
subdomains = np.copy(marker)
subdomains[np.isin(marker, [1,2])] = fluid_id
subdomains[np.isin(marker, [3,4])] = porous_id
subdomains[np.isin(marker, [5])] = 3
subdomains[np.isin(marker, [6])] = 4
labels = np.copy(subdomains)
subdomains[np.isin(subdomains, [3,4])] = fluid_id
meshio_mesh = meshio.Mesh(point_array, [("tetra", cell_array)],
                       cell_data={"gmsh:physical": [marker.ravel()],
                                  "labels": [labels.ravel()],
                                  "subdomains": [subdomains.ravel()]})
meshio_mesh.write("mesh/idealized.xdmf")

# %% [markdown]
# Finally, we check the resulting mesh by reading it back in and plotting it:

# %%
pv_mesh = pv.read_meshio("mesh/idealized.xdmf").clean() # changed from pv.read to pv.read_meshio
pv_mesh.clip(normal=(1,0,0),crinkle=True).plot("subdomains" ,show_edges=True, background="white")
# Out:
# /var/folders/86/ypcw7b6x6kx7ctt5dslpqwz40000gn/T/ipykernel_49565/2742215626.py:2: PyVistaDeprecationWarning:
# ../../../../var/folders/86/ypcw7b6x6kx7ctt5dslpqwz40000gn/T/ipykernel_49565/2742215626.py:2: Argument 'off_screen' must be passed as a keyword argument to function 'plot'.
# From version 0.50, passing this as a positional argument will result in a TypeError.
#   pv_mesh.clip(normal=(1,0,0),crinkle=True).plot("subdomains" ,show_edges=True, background="white")
# /Users/ingvildsd/miniforge3/envs/brainpulse_new/lib/python3.13/site-packages/pyvista/jupyter/notebook.py:56: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %% [markdown]
# ### Generating subdomain restrictions for Multiphenics
#
# To create function spaces restricted to a subdomain of the whole mesh with *MultiPhenics*, we need to create and save so-called *MeshRestrictions* prior to the main simulation run:

# %%
from fenics import *
from multiphenics import *

def generate_subdomain_restriction(mesh, subdomains, subdomain_id):
    D = mesh.topology().dim()
    # Initialize empty restriction
    restriction = MeshRestriction(mesh, None)
    for d in range(D + 1):
        mesh_function_d = MeshFunction("bool", mesh, d)
        mesh_function_d.set_all(False)
        restriction.append(mesh_function_d)
    # Mark restriction mesh functions based on subdomain id
    for c in cells(mesh):
        if subdomains[c] == subdomain_id:
            restriction[D][c] = True
            for d in range(D):
                for e in entities(c, d):
                    restriction[d][e] = True
    # Return
    return restriction
# Out:
# /Users/ingvildsd/miniforge3/envs/brainpulse_new/lib/python3.13/site-packages/ufl/__init__.py:250: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
fenics_mesh = Mesh()
with XDMFFile("mesh/idealized.xdmf") as f:
    f.read(fenics_mesh)
    sm = MeshFunction("size_t", fenics_mesh, 3, 0)
    labels = MeshFunction("size_t", fenics_mesh, 3, 0)
    f.read(sm, "subdomains")
    f.read(labels, "labels")
    sm.rename("subdomains","")

fluid_restr = generate_subdomain_restriction(fenics_mesh, sm, fluid_id)
porous_restr = generate_subdomain_restriction(fenics_mesh, sm, porous_id)
fluid_restr._write("mesh/idealized_fluid.rtc.xdmf")
porous_restr._write("mesh/idealized_porous.rtc.xdmf")

# %% [markdown]
# ## Marking Boundaries and Interfaces
# We mark both the internal interface by looping over all facets in the mesh, checking the subdomain ids of the corresponding cells and identifying the internal interfaces.
# In addition to the tissue-CSF interface, we also mark the surface between the aqueduct and the fourth ventricle, since we would like to compute aqueduct flow rates in the post-processing step.

# %%
bm = MeshFunction("size_t", fenics_mesh, 2, 0)

def mark_internal_interface(mesh, subdomains, bm, interface_id,
                            doms=None):
    # set internal interface
    for f in facets(mesh):
        domains = []
        for c in cells(f):
            domains.append(subdomains[c])
        domains = set(domains)
        if len(domains)==2:
            if doms is None:
                bm[f] = interface_id
            elif set(doms)==domains:
                bm[f] = interface_id

# mark tissue-CSF interface
mark_internal_interface(fenics_mesh, sm, bm, interface_id)
# mark aqueduct-fourth ventricle interface for later flow computation
mark_internal_interface(fenics_mesh, labels, bm, aqueduct_V4_id, doms=[3,4])

# %% [markdown]
# Similarly, we mark the external boundaries by a combination of the facet location and the subdomain id of the corresponding subdomain:

# %%
def mark_external_boundaries(mesh, subdomains, boundaries, 
                             subdomain_ids, new_boundary_id):
    for f in facets(mesh):
        if not f.exterior():
            continue
        c = list(cells(f))[0]
        if subdomains[c] in subdomain_ids:
            boundaries[f] = new_boundary_id
                
z_min = fenics_mesh.coordinates()[:,2].min()
bottom = CompiledSubDomain("on_boundary && near(x[2], v, tol)",
                        v=z_min, tol=0.001)
outer = CompiledSubDomain("on_boundary")
outer.mark(bm, skull_id)
bottom.mark(bm, spinal_canal_id)
mark_external_boundaries(fenics_mesh, sm, bm, 
                         [porous_id], spinal_cord_id)

with XDMFFile("mesh/idealized_boundaries.xdmf") as f:
    f.write(bm)
with XDMFFile("mesh/idealized.xdmf") as f:
    f.write(sm)
